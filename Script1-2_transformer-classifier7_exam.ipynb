# %% [markdown]
# ## 시험 스크립트 1-2 : 스크립트2에서 저장된 데이터셋 10개를 가지고 각각에 대해 10번의 모델 훈련을 수행하며 Precision, Recall, F1-score 과 그 평균 값들을 구해 averages_1481_i.csv 에 저장 (총 100번의 훈련과 각 지표마다 100개의 기록)

# %% [markdown]
# # Multi-Class Classification with Transformer Encoder

# %% [markdown]
# ## 1. Loading helper modules & functions

# %%
# %load_ext autoreload
# %autoreload 2
import torch as T
import torch.nn as nn
import pandas as pd
import numpy as np
import h5py
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import torchinfo
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  # Arrange GPU devices starting from 0
# os.environ["CUDA_VISIBLE_DEVICES"]= "0,1"  # Set the GPU 2 to use
device = T.device("cuda" if T.cuda.is_available() else "cpu")
device2 = T.device("cuda:1" if T.cuda.is_available() else "cpu")
# device = T.device("cpu")
# from encoding.parallel import DataParallelModel, DataParallelCriterion
from torchmetrics import MetricCollection
from torchmetrics.classification import MulticlassAccuracy, MulticlassPrecision, MulticlassRecall, MulticlassF1Score, MulticlassConfusionMatrix
metric_collection = MetricCollection([
    # MulticlassAccuracy(num_classes=4, average="none").to(device),
    MulticlassPrecision(num_classes=4, average="none").to(device),
    MulticlassRecall(num_classes=4, average="none").to(device),
    MulticlassF1Score(num_classes=4, average="none").to(device),
])
metric_collection_weighted = MetricCollection([
    # MulticlassAccuracy(num_classes=4, average="weighted").to(device),
    MulticlassPrecision(num_classes=4, average="weighted").to(device),
    MulticlassRecall(num_classes=4, average="weighted").to(device),
    MulticlassF1Score(num_classes=4, average="weighted").to(device),
])
# import sklearn.datasets
from sklearn.model_selection import train_test_split
# import umap
# import umap.plot
# import shap
# import scipy as sp
# import transformers
print("Pytorch version:", T.__version__, "CUDA version:", T.version.cuda, "cuDNN version:", T.backends.cudnn.version())
print("device:", device, T.cuda.get_device_name(0), ", device2:", device2, T.cuda.get_device_name(1))
# Out:
# Pytorch version: 1.12.1 CUDA version: 11.3 cuDNN version: 8302
# device: cuda NVIDIA RTX A6000 , device2: cuda:1 NVIDIA RTX A6000

# %% [markdown]
# ## 2. Implementing backbone of Transformer-based Classifier

# %%
# feature 개수 확인 및 설정
hf = h5py.File('STAD_Dataset3_minus_20_exam_0.h5', 'r')
X_DATA = np.array(hf.get('X'))
Y_DATA = np.array(hf.get('Y'))
print('X_DATA.shape :', X_DATA.shape, ', X_DATA.dtype :', X_DATA.dtype)
print('Y_DATA.shape :', Y_DATA.shape, '     , Y_DATA.dtype :', Y_DATA.dtype)
hf.close()

n_feature = X_DATA.shape[1]
print("\nThe number of feature :", n_feature)
# Out:
# X_DATA.shape : (407, 1481) , X_DATA.dtype : float64
# Y_DATA.shape : (407,)      , Y_DATA.dtype : int8
#
# The number of feature : 1481

# %%
class STAD_Dataset(T.utils.data.Dataset):
    def __init__(self, src_file):
        hf = h5py.File(src_file, 'r')
        if 'X_Train' in hf.keys() :
            # x = np.array(hf.get('X_Train')).astype('int64')
            x = np.array(hf.get('X_Train'))
            y = np.array(hf.get('Y_Train')).astype('int8')
        else :
            # x = np.array(hf.get('X_Test')).astype('int64')
            x = np.array(hf.get('X_Test'))
            y = np.array(hf.get('Y_Test')).astype('int8')
        hf.close()

        # self.x_data = T.tensor(x, dtype=T.int64).to(device)
        self.x_data = T.tensor(x, dtype=T.float32).to(device)
        self.y_data = T.tensor(y, dtype=T.int64).to(device)  

    def __len__(self):
        return len(self.x_data)

    def __getitem__(self, idx):
        x = self.x_data[idx]
        y = self.y_data[idx] 
        return x, y

# %%
class PositionalEncoding(T.nn.Module):  
    def __init__(self, d_model: int, dropout: float=0.1, max_len: int=n_feature):
        super(PositionalEncoding, self).__init__()  
        self.dropout = T.nn.Dropout(p=dropout)
        pe = T.zeros(max_len, d_model)  
        position = T.arange(0, max_len, dtype=T.float32).unsqueeze(1)
        div_term = T.exp(T.arange(0, d_model, 2).float() * (-np.log(10_000.0) / d_model))
        pe[:, 0::2] = T.sin(position * div_term)
        pe[:, 1::2] = T.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)  # 이게 없으면 나중에 forward 에서 pe값을 못 찾아 에러남

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

# %%
# E = number of cases that all features can express in integer (feature=token) 
# D = #Embedding Dimension ; I = #input features ; F = #fc1 layer hidden nodes ; drop = dropout rate
E = 320 ; D = 8 ; I = n_feature ; F = 8 ; drop = 0.1
class Transformer_Classifier(T.nn.Module):  # 1501 -> 12008 -> Transformer -> FC -> 4
    def __init__(self):
        super(Transformer_Classifier, self).__init__() 
        # numeric pseudo-embedding, dim=D
        # self.embed = Special_Embedding_Layer(I, I*D)  # I input features, each goes to D 
        self.embed = T.nn.Embedding(E, D)  # I input features, each goes to D
        self.pos_enc = PositionalEncoding(D, dropout=drop)  # positional embedding
        self.enc_layer = T.nn.TransformerEncoderLayer(d_model=D, nhead=4, dim_feedforward=D, 
                         dropout=drop, batch_first=True)  # d_model should be divisible by nhead
        self.trans_enc = T.nn.TransformerEncoder(self.enc_layer, num_layers=3)  # default 6 layers 
        # STAD Dataset has I input features per each sample
        self.dropout = nn.Dropout(drop)
        # self.fc1 = T.nn.Linear(D*I, F)  # F hidden nodes
        # self.fc2 = T.nn.Linear(F, 4)    # 4 classes
        self.fc3 = T.nn.Linear(D*I, 4)    # 4 classes (GX, G1, G2, G3)

    def forward(self, x):
        # x = I input features, fixed length
        z = self.embed(x.int())  # I inputs to I*D embeds
        z = z.reshape(-1, I, D) 
        z = self.pos_enc(z) 
        z = self.trans_enc(z) 
        z = z.reshape(-1, D*I)  # torch.Size([batch_size, D*I])
        # z = self.dropout(z)
        # z = self.fc1(z)
        # z = T.tanh(z)
        z = self.dropout(z)
        z = self.fc3(z)
        z = T.log_softmax(z, dim=1)  # later followed by NLL Loss()
        return z

# %% [markdown]
# ## 3. Training model

# %%
for j in range(10):
    # feature 개수 확인 및 설정
    hf = h5py.File(f'STAD_Dataset3_minus_20_exam_{j}.h5', 'r')
    X_DATA = np.array(hf.get('X'))
    Y_DATA = np.array(hf.get('Y'))
    hf.close()

    print(f'STAD_Dataset3_minus_20_exam_{j}.h5 dataset loaded\n')

    max_F1 = 0
    precision_list_10 = []
    recall_list_10 = []
    f1score_list_10 = []

    for i in range(10):

        print("############################## Trining", j+1, "-", i+1, "##############################\n")

        ########## 3-0. Data Random Splitting ##########

        # 1. Train : Test 를 레이블 비율을 균등하게 유지하면서 8 : 2로 랜덤하게 나눔
        X_Train, X_Test, Y_Train, Y_Test = train_test_split(X_DATA, Y_DATA, test_size=0.2, stratify=Y_DATA, random_state=(2*i+1))

        # 2. Train 데이터 파일로 저장
        hf = h5py.File('STAD_Dataset3_Train_minus_20_exam.h5', 'w')
        hf.create_dataset('X_Train', data=X_Train)
        hf.create_dataset('Y_Train', data=Y_Train)
        hf.close()
        # 3. Test 데이터 파일로 저장 
        hf = h5py.File('STAD_Dataset3_Test_minus_20_exam.h5', 'w')
        hf.create_dataset('X_Test', data=X_Test)
        hf.create_dataset('Y_Test', data=Y_Test)
        hf.close()

        ########## 3-1. Lodaing Dataset ##########

        # 0. setup
        np.random.seed(1)  
        T.manual_seed(1)  

        # 1. create Dataset
        train_file = "./STAD_Dataset3_Train_minus_20_exam.h5"
        train_ds = STAD_Dataset(train_file)

        test_file = "./STAD_Dataset3_Test_minus_20_exam.h5"
        test_ds = STAD_Dataset(test_file)

        bat_size = 8
        train_ldr = T.utils.data.DataLoader(train_ds, batch_size=bat_size, shuffle=True)
        # test_ldr = T.utils.data.DataLoader(test_ds, batch_size=2, shuffle=False)

        ########## 3-2. Training model ##########

        # net = Transformer_Classifier().to(device)
        net = nn.DataParallel(Transformer_Classifier()).to(device)

        max_epochs = 18
        ep_log_interval = 1
        lrn_rate = 0.0001

        loss_func = T.nn.NLLLoss()  # assumes log-softmax()
        # loss_func = DataParallelCriterion(T.nn.NLLLoss())  # assumes log-softmax()
        optimizer = T.optim.Adam(net.parameters(), lr=lrn_rate, weight_decay=0.1)
        scheduler = T.optim.lr_scheduler.LambdaLR(optimizer=optimizer, lr_lambda=lambda epoch: 0.99 ** epoch, last_epoch=-1, verbose=False)

        net.train()  # set mode

        loss_list = []
        accuracy_list = []
        test_accuracy_list = []
        for epoch in range(0, max_epochs):
            ep_loss = 0.0  # for one full epoch
            for (X, y) in train_ldr: # X = genes, y = labels
                optimizer.zero_grad()
                # with T.autocast(device_type="cuda"): # for auto-mixed precision
                oupt = net(X)
                loss_val = loss_func(oupt, y)  # a tensor
                
                ep_loss += loss_val.item()  # accumulate
                loss_val.backward()  # compute grads
                optimizer.step()     # update weights
            if epoch % ep_log_interval == 0:
                print("epoch = %4d  |  loss = %8.4f  |  lr = %8.8f" % (epoch+1, ep_loss/bat_size, optimizer.param_groups[0]['lr']))
                # net.eval()
            scheduler.step()

        print("Done ") 

        net.eval()
        with T.no_grad():
            output_test = net(test_ds.x_data)
        target_test = test_ds.y_data
        preds_test  = output_test.argmax(dim=1, keepdim=True).squeeze(1)
        print(metric_collection_weighted(preds_test, target_test),'\n')

        # 시험2를 위한
        precision_list_10.append(MulticlassPrecision(num_classes=4, average="weighted").to(device)(preds_test, target_test))    
        recall_list_10.append(MulticlassRecall(num_classes=4, average="weighted").to(device)(preds_test, target_test))    
        f1score_list_10.append(MulticlassF1Score(num_classes=4, average="weighted").to(device)(preds_test, target_test))    

    ### 10번 훈련에서의 각 precision 값들과 그 평균
    precision_sum = 0
    for p in precision_list_10:
        precision_sum += p
    ### 10번 훈련에서의 각 recall 값들과 그 평균
    recall_sum = 0
    for p in recall_list_10:
        recall_sum += p
    ### 10번 훈련에서의 각 F1-Score 값들과 그 평균
    f1score_sum = 0
    for p in f1score_list_10:
        f1score_sum += p

    ### 각종 값들과 평균 csv 파일로 저장
    precision_list = [p.detach().cpu().numpy() for p in precision_list_10]
    precision_list.append((precision_sum/10).detach().cpu().numpy())
    recall_list = [p.detach().cpu().numpy() for p in recall_list_10]
    recall_list.append((recall_sum/10).detach().cpu().numpy())
    f1score_list = [p.detach().cpu().numpy() for p in f1score_list_10]
    f1score_list.append((f1score_sum/10).detach().cpu().numpy())

    averages_1501_df = pd.DataFrame({'Train':np.arange(1,len(precision_list)+1),
                                    'Precision':precision_list, 
                                    'Recall':recall_list, 
                                    'F1-Score':f1score_list})  
    averages_1501_df.iloc[(-1,0)] = '평균'

    averages_1501_df.to_csv(f'./averages_1481_{j}.csv')
    print(f'averages_1481_{j}.csv saved\n')
# Out:
# STAD_Dataset3_minus_20_exam_0.h5 dataset loaded
#
# ############################## Trining 1 - 1 ##############################
#
# epoch =    1  |  loss =   5.1508  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1588  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6476  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0118  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6271  |  lr = 0.00009606
# epoch =    6  |  loss =   2.2324  |  lr = 0.00009510
# epoch =    7  |  loss =   1.9061  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4026  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1335  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0211  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9514  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8054  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7147  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6225  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5782  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4943  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4541  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4065  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5841, device='cuda:0'), 'MulticlassRecall': tensor(0.5366, device='cuda:0'), 'MulticlassF1Score': tensor(0.5265, device='cuda:0')}
#
# ############################## Trining 1 - 2 ##############################
#
# epoch =    1  |  loss =   5.1716  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1807  |  lr = 0.00009900
# epoch =    3  |  loss =   3.9145  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1101  |  lr = 0.00009703
# epoch =    5  |  loss =   2.7058  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1865  |  lr = 0.00009510
# epoch =    7  |  loss =   1.9964  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6756  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3083  |  lr = 0.00009227
# epoch =   10  |  loss =   1.1235  |  lr = 0.00009135
# epoch =   11  |  loss =   1.0212  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8526  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7273  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6400  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5961  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5257  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4522  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4591  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4537, device='cuda:0'), 'MulticlassRecall': tensor(0.4634, device='cuda:0'), 'MulticlassF1Score': tensor(0.4567, device='cuda:0')}
#
# ############################## Trining 1 - 3 ##############################
#
# epoch =    1  |  loss =   5.5415  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2729  |  lr = 0.00009900
# epoch =    3  |  loss =   3.5991  |  lr = 0.00009801
# epoch =    4  |  loss =   3.3986  |  lr = 0.00009703
# epoch =    5  |  loss =   2.7512  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1224  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8238  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6000  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2989  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0182  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9609  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8002  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7286  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6474  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5795  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5554  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4796  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4297  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4913, device='cuda:0'), 'MulticlassRecall': tensor(0.4756, device='cuda:0'), 'MulticlassF1Score': tensor(0.4673, device='cuda:0')}
#
# ############################## Trining 1 - 4 ##############################
#
# epoch =    1  |  loss =   5.1968  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1785  |  lr = 0.00009900
# epoch =    3  |  loss =   3.7456  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1241  |  lr = 0.00009703
# epoch =    5  |  loss =   3.0076  |  lr = 0.00009606
# epoch =    6  |  loss =   2.2060  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8790  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4970  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3141  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0633  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9146  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8306  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7458  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6564  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5850  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5170  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4633  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4439  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5495, device='cuda:0'), 'MulticlassRecall': tensor(0.5610, device='cuda:0'), 'MulticlassF1Score': tensor(0.5520, device='cuda:0')}
#
# ############################## Trining 1 - 5 ##############################
#
# epoch =    1  |  loss =   4.9914  |  lr = 0.00010000
# epoch =    2  |  loss =   4.4057  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6195  |  lr = 0.00009801
# epoch =    4  |  loss =   3.2217  |  lr = 0.00009703
# epoch =    5  |  loss =   2.7241  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0960  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7621  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4079  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1905  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0861  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9134  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8150  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7136  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6064  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5545  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4901  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4582  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4278  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5009, device='cuda:0'), 'MulticlassRecall': tensor(0.5488, device='cuda:0'), 'MulticlassF1Score': tensor(0.5169, device='cuda:0')}
#
# ############################## Trining 1 - 6 ##############################
#
# epoch =    1  |  loss =   5.3060  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1586  |  lr = 0.00009900
# epoch =    3  |  loss =   3.5882  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1347  |  lr = 0.00009703
# epoch =    5  |  loss =   2.5876  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1290  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7539  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5085  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2870  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0347  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9449  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8063  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7060  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6557  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5270  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5127  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4742  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4134  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5409, device='cuda:0'), 'MulticlassRecall': tensor(0.5610, device='cuda:0'), 'MulticlassF1Score': tensor(0.5498, device='cuda:0')}
#
# ############################## Trining 1 - 7 ##############################
#
# epoch =    1  |  loss =   5.3956  |  lr = 0.00010000
# epoch =    2  |  loss =   4.4625  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6370  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1598  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6954  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0777  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7686  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5115  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2850  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0306  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8838  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8142  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6784  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6171  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5787  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4764  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4677  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4163  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4444, device='cuda:0'), 'MulticlassRecall': tensor(0.4390, device='cuda:0'), 'MulticlassF1Score': tensor(0.4365, device='cuda:0')}
#
# ############################## Trining 1 - 8 ##############################
#
# epoch =    1  |  loss =   4.9854  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1960  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6126  |  lr = 0.00009801
# epoch =    4  |  loss =   3.2270  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6885  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1746  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7397  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4291  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2197  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0365  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9470  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7813  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7352  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6385  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5277  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5020  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4697  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4408  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5139, device='cuda:0'), 'MulticlassRecall': tensor(0.5122, device='cuda:0'), 'MulticlassF1Score': tensor(0.5054, device='cuda:0')}
#
# ############################## Trining 1 - 9 ##############################
#
# epoch =    1  |  loss =   5.5413  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2917  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6824  |  lr = 0.00009801
# epoch =    4  |  loss =   3.2250  |  lr = 0.00009703
# epoch =    5  |  loss =   2.7666  |  lr = 0.00009606
# epoch =    6  |  loss =   2.2149  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7811  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6100  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3308  |  lr = 0.00009227
# epoch =   10  |  loss =   1.1095  |  lr = 0.00009135
# epoch =   11  |  loss =   1.0032  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8133  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7190  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6563  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5742  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5487  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4854  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4388  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4689, device='cuda:0'), 'MulticlassRecall': tensor(0.4390, device='cuda:0'), 'MulticlassF1Score': tensor(0.4376, device='cuda:0')}
#
# ############################## Trining 1 - 10 ##############################
#
# epoch =    1  |  loss =   5.4706  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2853  |  lr = 0.00009900
# epoch =    3  |  loss =   3.7631  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0685  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6637  |  lr = 0.00009606
# epoch =    6  |  loss =   2.2088  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8521  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6160  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2309  |  lr = 0.00009227
# epoch =   10  |  loss =   1.1304  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9607  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8302  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7089  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6742  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5644  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5193  |  lr = 0.00008601
# epoch =   17  |  loss =   0.5164  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4213  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4948, device='cuda:0'), 'MulticlassRecall': tensor(0.5000, device='cuda:0'), 'MulticlassF1Score': tensor(0.4925, device='cuda:0')}
#
# averages_1481_0.csv saved
#
# STAD_Dataset3_minus_20_exam_1.h5 dataset loaded
#
# ############################## Trining 2 - 1 ##############################
#
# epoch =    1  |  loss =   5.0458  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1180  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6398  |  lr = 0.00009801
# epoch =    4  |  loss =   2.9451  |  lr = 0.00009703
# epoch =    5  |  loss =   2.5600  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1159  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8941  |  lr = 0.00009415
# epoch =    8  |  loss =   1.3453  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1521  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0218  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9060  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8065  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6893  |  lr = 0.00008864
# epoch =   14  |  loss =   0.5807  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5842  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4722  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4562  |  lr = 0.00008515
# epoch =   18  |  loss =   0.3930  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5866, device='cuda:0'), 'MulticlassRecall': tensor(0.5244, device='cuda:0'), 'MulticlassF1Score': tensor(0.5102, device='cuda:0')}
#
# ############################## Trining 2 - 2 ##############################
#
# epoch =    1  |  loss =   5.1408  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1487  |  lr = 0.00009900
# epoch =    3  |  loss =   3.7765  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0217  |  lr = 0.00009703
# epoch =    5  |  loss =   2.5570  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1901  |  lr = 0.00009510
# epoch =    7  |  loss =   1.9196  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5698  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3010  |  lr = 0.00009227
# epoch =   10  |  loss =   1.1138  |  lr = 0.00009135
# epoch =   11  |  loss =   1.0078  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8544  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7275  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6425  |  lr = 0.00008775
# epoch =   15  |  loss =   0.6051  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5291  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4611  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4274  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4993, device='cuda:0'), 'MulticlassRecall': tensor(0.5000, device='cuda:0'), 'MulticlassF1Score': tensor(0.4921, device='cuda:0')}
#
# ############################## Trining 2 - 3 ##############################
#
# epoch =    1  |  loss =   5.5305  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1765  |  lr = 0.00009900
# epoch =    3  |  loss =   3.5532  |  lr = 0.00009801
# epoch =    4  |  loss =   3.3334  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6343  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0396  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7786  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5291  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2769  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0195  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9389  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8394  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6952  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6254  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5931  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5209  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4525  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4355  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5804, device='cuda:0'), 'MulticlassRecall': tensor(0.5488, device='cuda:0'), 'MulticlassF1Score': tensor(0.5338, device='cuda:0')}
#
# ############################## Trining 2 - 4 ##############################
#
# epoch =    1  |  loss =   5.1151  |  lr = 0.00010000
# epoch =    2  |  loss =   4.0951  |  lr = 0.00009900
# epoch =    3  |  loss =   3.7793  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1716  |  lr = 0.00009703
# epoch =    5  |  loss =   2.8647  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1481  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7188  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4490  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3330  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0904  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9217  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8138  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7307  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6402  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5594  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4985  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4582  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4491  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5730, device='cuda:0'), 'MulticlassRecall': tensor(0.5854, device='cuda:0'), 'MulticlassF1Score': tensor(0.5746, device='cuda:0')}
#
# ############################## Trining 2 - 5 ##############################
#
# epoch =    1  |  loss =   4.8813  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1892  |  lr = 0.00009900
# epoch =    3  |  loss =   3.4495  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0196  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6454  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9826  |  lr = 0.00009510
# epoch =    7  |  loss =   1.6671  |  lr = 0.00009415
# epoch =    8  |  loss =   1.3424  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1265  |  lr = 0.00009227
# epoch =   10  |  loss =   0.9993  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8692  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7333  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6751  |  lr = 0.00008864
# epoch =   14  |  loss =   0.5678  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5439  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4626  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4367  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4221  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4481, device='cuda:0'), 'MulticlassRecall': tensor(0.5000, device='cuda:0'), 'MulticlassF1Score': tensor(0.4671, device='cuda:0')}
#
# ############################## Trining 2 - 6 ##############################
#
# epoch =    1  |  loss =   5.3096  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1069  |  lr = 0.00009900
# epoch =    3  |  loss =   3.5612  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1304  |  lr = 0.00009703
# epoch =    5  |  loss =   2.5487  |  lr = 0.00009606
# epoch =    6  |  loss =   2.2071  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7854  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5388  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2889  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0431  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9191  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8267  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7146  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6738  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5397  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5411  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4959  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4122  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5867, device='cuda:0'), 'MulticlassRecall': tensor(0.6098, device='cuda:0'), 'MulticlassF1Score': tensor(0.5970, device='cuda:0')}
#
# ############################## Trining 2 - 7 ##############################
#
# epoch =    1  |  loss =   5.2596  |  lr = 0.00010000
# epoch =    2  |  loss =   4.3043  |  lr = 0.00009900
# epoch =    3  |  loss =   3.5653  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0825  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6361  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9810  |  lr = 0.00009510
# epoch =    7  |  loss =   1.6470  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5128  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2343  |  lr = 0.00009227
# epoch =   10  |  loss =   0.9723  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8569  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7721  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6825  |  lr = 0.00008864
# epoch =   14  |  loss =   0.5449  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5326  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4779  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4544  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4155  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4795, device='cuda:0'), 'MulticlassRecall': tensor(0.5000, device='cuda:0'), 'MulticlassF1Score': tensor(0.4894, device='cuda:0')}
#
# ############################## Trining 2 - 8 ##############################
#
# epoch =    1  |  loss =   4.8924  |  lr = 0.00010000
# epoch =    2  |  loss =   4.0972  |  lr = 0.00009900
# epoch =    3  |  loss =   3.5058  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1876  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6164  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0986  |  lr = 0.00009510
# epoch =    7  |  loss =   1.6804  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4328  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1652  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0394  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9092  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7746  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7206  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6268  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5119  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4927  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4658  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4249  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4854, device='cuda:0'), 'MulticlassRecall': tensor(0.4878, device='cuda:0'), 'MulticlassF1Score': tensor(0.4806, device='cuda:0')}
#
# ############################## Trining 2 - 9 ##############################
#
# epoch =    1  |  loss =   5.4547  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2006  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6146  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1585  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6853  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1815  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7339  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5745  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3009  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0758  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9360  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8308  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7232  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6513  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5744  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5302  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4988  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4292  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5242, device='cuda:0'), 'MulticlassRecall': tensor(0.4756, device='cuda:0'), 'MulticlassF1Score': tensor(0.4673, device='cuda:0')}
#
# ############################## Trining 2 - 10 ##############################
#
# epoch =    1  |  loss =   5.4074  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1402  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6236  |  lr = 0.00009801
# epoch =    4  |  loss =   2.9532  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6536  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0906  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7671  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5659  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2103  |  lr = 0.00009227
# epoch =   10  |  loss =   1.1037  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8885  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8070  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6891  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6466  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5507  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4785  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4640  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4197  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5312, device='cuda:0'), 'MulticlassRecall': tensor(0.5122, device='cuda:0'), 'MulticlassF1Score': tensor(0.5017, device='cuda:0')}
#
# averages_1481_1.csv saved
#
# STAD_Dataset3_minus_20_exam_2.h5 dataset loaded
#
# ############################## Trining 3 - 1 ##############################
#
# epoch =    1  |  loss =   5.0300  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2004  |  lr = 0.00009900
# epoch =    3  |  loss =   3.7005  |  lr = 0.00009801
# epoch =    4  |  loss =   2.9544  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6422  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1790  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8713  |  lr = 0.00009415
# epoch =    8  |  loss =   1.3465  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1554  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0282  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8826  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8315  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7128  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6377  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5768  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4660  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4378  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4073  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5921, device='cuda:0'), 'MulticlassRecall': tensor(0.5488, device='cuda:0'), 'MulticlassF1Score': tensor(0.5396, device='cuda:0')}
#
# ############################## Trining 3 - 2 ##############################
#
# epoch =    1  |  loss =   5.2137  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1280  |  lr = 0.00009900
# epoch =    3  |  loss =   3.9415  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0555  |  lr = 0.00009703
# epoch =    5  |  loss =   2.5849  |  lr = 0.00009606
# epoch =    6  |  loss =   2.2421  |  lr = 0.00009510
# epoch =    7  |  loss =   1.9939  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5289  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3123  |  lr = 0.00009227
# epoch =   10  |  loss =   1.1137  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9661  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8352  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7120  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6569  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5821  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5190  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4831  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4465  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4536, device='cuda:0'), 'MulticlassRecall': tensor(0.4756, device='cuda:0'), 'MulticlassF1Score': tensor(0.4643, device='cuda:0')}
#
# ############################## Trining 3 - 3 ##############################
#
# epoch =    1  |  loss =   5.4333  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2233  |  lr = 0.00009900
# epoch =    3  |  loss =   3.5249  |  lr = 0.00009801
# epoch =    4  |  loss =   3.3939  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6626  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0649  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7987  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4969  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2681  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0181  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9683  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8224  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7174  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6293  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5674  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5341  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4712  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4122  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4813, device='cuda:0'), 'MulticlassRecall': tensor(0.4756, device='cuda:0'), 'MulticlassF1Score': tensor(0.4699, device='cuda:0')}
#
# ############################## Trining 3 - 4 ##############################
#
# epoch =    1  |  loss =   5.1845  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1066  |  lr = 0.00009900
# epoch =    3  |  loss =   3.8194  |  lr = 0.00009801
# epoch =    4  |  loss =   3.2273  |  lr = 0.00009703
# epoch =    5  |  loss =   2.9530  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1644  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7857  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4504  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3569  |  lr = 0.00009227
# epoch =   10  |  loss =   1.1272  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8958  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8208  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7300  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6344  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5890  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5282  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4670  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4582  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5125, device='cuda:0'), 'MulticlassRecall': tensor(0.5244, device='cuda:0'), 'MulticlassF1Score': tensor(0.5163, device='cuda:0')}
#
# ############################## Trining 3 - 5 ##############################
#
# epoch =    1  |  loss =   4.9346  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2448  |  lr = 0.00009900
# epoch =    3  |  loss =   3.5961  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0741  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6752  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0805  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7559  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4053  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1553  |  lr = 0.00009227
# epoch =   10  |  loss =   0.9900  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8810  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7888  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6914  |  lr = 0.00008864
# epoch =   14  |  loss =   0.5912  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5286  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4890  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4529  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4110  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4603, device='cuda:0'), 'MulticlassRecall': tensor(0.5000, device='cuda:0'), 'MulticlassF1Score': tensor(0.4765, device='cuda:0')}
#
# ############################## Trining 3 - 6 ##############################
#
# epoch =    1  |  loss =   5.3335  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2506  |  lr = 0.00009900
# epoch =    3  |  loss =   3.5657  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1566  |  lr = 0.00009703
# epoch =    5  |  loss =   2.5639  |  lr = 0.00009606
# epoch =    6  |  loss =   2.2652  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8352  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5854  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3865  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0041  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8916  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7763  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7201  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6722  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5437  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5244  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4587  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4319  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5092, device='cuda:0'), 'MulticlassRecall': tensor(0.5366, device='cuda:0'), 'MulticlassF1Score': tensor(0.5225, device='cuda:0')}
#
# ############################## Trining 3 - 7 ##############################
#
# epoch =    1  |  loss =   5.3364  |  lr = 0.00010000
# epoch =    2  |  loss =   4.3588  |  lr = 0.00009900
# epoch =    3  |  loss =   3.7512  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0763  |  lr = 0.00009703
# epoch =    5  |  loss =   2.5941  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0123  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7133  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4593  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2318  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0185  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8768  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7704  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6797  |  lr = 0.00008864
# epoch =   14  |  loss =   0.5703  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5429  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4877  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4460  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4134  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4211, device='cuda:0'), 'MulticlassRecall': tensor(0.4268, device='cuda:0'), 'MulticlassF1Score': tensor(0.4226, device='cuda:0')}
#
# ############################## Trining 3 - 8 ##############################
#
# epoch =    1  |  loss =   4.9678  |  lr = 0.00010000
# epoch =    2  |  loss =   4.0778  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6210  |  lr = 0.00009801
# epoch =    4  |  loss =   3.2329  |  lr = 0.00009703
# epoch =    5  |  loss =   2.7093  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0637  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8194  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4561  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1618  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0273  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8949  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7668  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7046  |  lr = 0.00008864
# epoch =   14  |  loss =   0.5825  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5593  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5249  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4268  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4571  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5176, device='cuda:0'), 'MulticlassRecall': tensor(0.5244, device='cuda:0'), 'MulticlassF1Score': tensor(0.5174, device='cuda:0')}
#
# ############################## Trining 3 - 9 ##############################
#
# epoch =    1  |  loss =   5.3856  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2300  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6630  |  lr = 0.00009801
# epoch =    4  |  loss =   3.2151  |  lr = 0.00009703
# epoch =    5  |  loss =   2.7161  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1518  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7394  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5686  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2612  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0950  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9829  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8563  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6954  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6529  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5895  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5300  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4991  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4409  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4878, device='cuda:0'), 'MulticlassRecall': tensor(0.4634, device='cuda:0'), 'MulticlassF1Score': tensor(0.4627, device='cuda:0')}
#
# ############################## Trining 3 - 10 ##############################
#
# epoch =    1  |  loss =   5.4622  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2194  |  lr = 0.00009900
# epoch =    3  |  loss =   3.7588  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0573  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6745  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1817  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7867  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6431  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2261  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0812  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9270  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8418  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7106  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6806  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5609  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4757  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4758  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4452  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4795, device='cuda:0'), 'MulticlassRecall': tensor(0.5000, device='cuda:0'), 'MulticlassF1Score': tensor(0.4894, device='cuda:0')}
#
# averages_1481_2.csv saved
#
# STAD_Dataset3_minus_20_exam_3.h5 dataset loaded
#
# ############################## Trining 4 - 1 ##############################
#
# epoch =    1  |  loss =   5.1980  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1585  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6646  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0490  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6786  |  lr = 0.00009606
# epoch =    6  |  loss =   2.2392  |  lr = 0.00009510
# epoch =    7  |  loss =   1.9300  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4508  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1642  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0713  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9636  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8424  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7297  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6419  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5792  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4972  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4632  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4115  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5661, device='cuda:0'), 'MulticlassRecall': tensor(0.5244, device='cuda:0'), 'MulticlassF1Score': tensor(0.5157, device='cuda:0')}
#
# ############################## Trining 4 - 2 ##############################
#
# epoch =    1  |  loss =   5.2423  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2042  |  lr = 0.00009900
# epoch =    3  |  loss =   3.9051  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0920  |  lr = 0.00009703
# epoch =    5  |  loss =   2.7435  |  lr = 0.00009606
# epoch =    6  |  loss =   2.2406  |  lr = 0.00009510
# epoch =    7  |  loss =   1.9598  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6398  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3558  |  lr = 0.00009227
# epoch =   10  |  loss =   1.1352  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9894  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8728  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7312  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6524  |  lr = 0.00008775
# epoch =   15  |  loss =   0.6149  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5344  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4691  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4565  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5087, device='cuda:0'), 'MulticlassRecall': tensor(0.5244, device='cuda:0'), 'MulticlassF1Score': tensor(0.5150, device='cuda:0')}
#
# ############################## Trining 4 - 3 ##############################
#
# epoch =    1  |  loss =   5.6052  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2919  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6018  |  lr = 0.00009801
# epoch =    4  |  loss =   3.4118  |  lr = 0.00009703
# epoch =    5  |  loss =   2.7949  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1539  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8999  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6655  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3476  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0692  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9872  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8222  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7394  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6566  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5984  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5601  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4994  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4366  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5432, device='cuda:0'), 'MulticlassRecall': tensor(0.5000, device='cuda:0'), 'MulticlassF1Score': tensor(0.4790, device='cuda:0')}
#
# ############################## Trining 4 - 4 ##############################
#
# epoch =    1  |  loss =   5.2867  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2590  |  lr = 0.00009900
# epoch =    3  |  loss =   3.9040  |  lr = 0.00009801
# epoch =    4  |  loss =   3.2470  |  lr = 0.00009703
# epoch =    5  |  loss =   3.1240  |  lr = 0.00009606
# epoch =    6  |  loss =   2.2747  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8956  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5213  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3734  |  lr = 0.00009227
# epoch =   10  |  loss =   1.1153  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9390  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8786  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7703  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6693  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5964  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5228  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4974  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4665  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5460, device='cuda:0'), 'MulticlassRecall': tensor(0.5488, device='cuda:0'), 'MulticlassF1Score': tensor(0.5390, device='cuda:0')}
#
# ############################## Trining 4 - 5 ##############################
#
# epoch =    1  |  loss =   5.0324  |  lr = 0.00010000
# epoch =    2  |  loss =   4.4339  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6530  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1769  |  lr = 0.00009703
# epoch =    5  |  loss =   2.7467  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1260  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7825  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4625  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1984  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0868  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9396  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8114  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7248  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6358  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5861  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5062  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4564  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4234  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4961, device='cuda:0'), 'MulticlassRecall': tensor(0.5366, device='cuda:0'), 'MulticlassF1Score': tensor(0.5134, device='cuda:0')}
#
# ############################## Trining 4 - 6 ##############################
#
# epoch =    1  |  loss =   5.4142  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2595  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6727  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1298  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6697  |  lr = 0.00009606
# epoch =    6  |  loss =   2.2646  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8732  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5701  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3232  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0796  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9376  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8352  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7134  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6753  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5470  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5217  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4898  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4161  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5827, device='cuda:0'), 'MulticlassRecall': tensor(0.6098, device='cuda:0'), 'MulticlassF1Score': tensor(0.5957, device='cuda:0')}
#
# ############################## Trining 4 - 7 ##############################
#
# epoch =    1  |  loss =   5.3742  |  lr = 0.00010000
# epoch =    2  |  loss =   4.4482  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6137  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1337  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6927  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0639  |  lr = 0.00009510
# epoch =    7  |  loss =   1.6980  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5377  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2763  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0430  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8827  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7669  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7340  |  lr = 0.00008864
# epoch =   14  |  loss =   0.5722  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5783  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4880  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4584  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4120  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.3873, device='cuda:0'), 'MulticlassRecall': tensor(0.3780, device='cuda:0'), 'MulticlassF1Score': tensor(0.3760, device='cuda:0')}
#
# ############################## Trining 4 - 8 ##############################
#
# epoch =    1  |  loss =   5.0146  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1376  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6255  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1967  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6903  |  lr = 0.00009606
# epoch =    6  |  loss =   2.2124  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7901  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4733  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2250  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0735  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9605  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7576  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7432  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6506  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5333  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4860  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4701  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4613  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4714, device='cuda:0'), 'MulticlassRecall': tensor(0.4512, device='cuda:0'), 'MulticlassF1Score': tensor(0.4413, device='cuda:0')}
#
# ############################## Trining 4 - 9 ##############################
#
# epoch =    1  |  loss =   5.5881  |  lr = 0.00010000
# epoch =    2  |  loss =   4.3007  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6672  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1354  |  lr = 0.00009703
# epoch =    5  |  loss =   2.7584  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1911  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7653  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6312  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3158  |  lr = 0.00009227
# epoch =   10  |  loss =   1.1498  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9964  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8540  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7367  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6722  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5553  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5331  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4966  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4277  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4698, device='cuda:0'), 'MulticlassRecall': tensor(0.4268, device='cuda:0'), 'MulticlassF1Score': tensor(0.4191, device='cuda:0')}
#
# ############################## Trining 4 - 10 ##############################
#
# epoch =    1  |  loss =   5.5617  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2319  |  lr = 0.00009900
# epoch =    3  |  loss =   3.7030  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0763  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6323  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1517  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8150  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6274  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2635  |  lr = 0.00009227
# epoch =   10  |  loss =   1.1307  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9676  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8383  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7018  |  lr = 0.00008864
# ...
# epoch =   18  |  loss =   0.4071  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4263, device='cuda:0'), 'MulticlassRecall': tensor(0.4390, device='cuda:0'), 'MulticlassF1Score': tensor(0.4319, device='cuda:0')}
#
# ############################## Trining 9 - 8 ##############################
#
# epoch =    1  |  loss =   4.9491  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1204  |  lr = 0.00009900
# epoch =    3  |  loss =   3.5357  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1553  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6381  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1131  |  lr = 0.00009510
# epoch =    7  |  loss =   1.6955  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4166  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1497  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0280  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8546  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7733  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7167  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6099  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5409  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4813  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4718  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4275  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4663, device='cuda:0'), 'MulticlassRecall': tensor(0.4634, device='cuda:0'), 'MulticlassF1Score': tensor(0.4564, device='cuda:0')}
#
# ############################## Trining 9 - 9 ##############################
#
# epoch =    1  |  loss =   5.4636  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2484  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6056  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1376  |  lr = 0.00009703
# epoch =    5  |  loss =   2.7450  |  lr = 0.00009606
# epoch =    6  |  loss =   2.2284  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7035  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5482  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2591  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0501  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9525  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8323  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7338  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6530  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5640  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5142  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4955  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4405  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5335, device='cuda:0'), 'MulticlassRecall': tensor(0.5000, device='cuda:0'), 'MulticlassF1Score': tensor(0.4926, device='cuda:0')}
#
# ############################## Trining 9 - 10 ##############################
#
# epoch =    1  |  loss =   5.2986  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1788  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6300  |  lr = 0.00009801
# epoch =    4  |  loss =   2.9649  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6087  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1401  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7858  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4786  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2116  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0634  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8725  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7832  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6603  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6370  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5526  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4940  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4783  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4168  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4813, device='cuda:0'), 'MulticlassRecall': tensor(0.5000, device='cuda:0'), 'MulticlassF1Score': tensor(0.4901, device='cuda:0')}
#
# averages_1481_8.csv saved
#
# STAD_Dataset3_minus_20_exam_9.h5 dataset loaded
#
# ############################## Trining 10 - 1 ##############################
#
# epoch =    1  |  loss =   5.1552  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1371  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6922  |  lr = 0.00009801
# epoch =    4  |  loss =   2.9797  |  lr = 0.00009703
# epoch =    5  |  loss =   2.5867  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1544  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8239  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4166  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1605  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0119  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8945  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8192  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6808  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6167  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5728  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4718  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4593  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4080  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5502, device='cuda:0'), 'MulticlassRecall': tensor(0.5366, device='cuda:0'), 'MulticlassF1Score': tensor(0.5319, device='cuda:0')}
#
# ############################## Trining 10 - 2 ##############################
#
# epoch =    1  |  loss =   5.2472  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2282  |  lr = 0.00009900
# epoch =    3  |  loss =   3.9649  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0915  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6793  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1888  |  lr = 0.00009510
# epoch =    7  |  loss =   1.9697  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5762  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3648  |  lr = 0.00009227
# epoch =   10  |  loss =   1.1303  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9730  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8201  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7099  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6425  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5843  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5282  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4817  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4404  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5453, device='cuda:0'), 'MulticlassRecall': tensor(0.5610, device='cuda:0'), 'MulticlassF1Score': tensor(0.5507, device='cuda:0')}
#
# ############################## Trining 10 - 3 ##############################
#
# epoch =    1  |  loss =   5.4227  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1939  |  lr = 0.00009900
# epoch =    3  |  loss =   3.5059  |  lr = 0.00009801
# epoch =    4  |  loss =   3.3956  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6698  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0438  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7809  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4527  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2293  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0218  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9236  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8213  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6963  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6220  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5416  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5066  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4732  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4108  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5406, device='cuda:0'), 'MulticlassRecall': tensor(0.5488, device='cuda:0'), 'MulticlassF1Score': tensor(0.5405, device='cuda:0')}
#
# ############################## Trining 10 - 4 ##############################
#
# epoch =    1  |  loss =   5.1008  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1176  |  lr = 0.00009900
# epoch =    3  |  loss =   3.7182  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1119  |  lr = 0.00009703
# epoch =    5  |  loss =   2.8744  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1643  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7372  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4044  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2534  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0566  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9251  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7928  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7267  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6073  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5708  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4971  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4699  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4300  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4813, device='cuda:0'), 'MulticlassRecall': tensor(0.4756, device='cuda:0'), 'MulticlassF1Score': tensor(0.4699, device='cuda:0')}
#
# ############################## Trining 10 - 5 ##############################
#
# epoch =    1  |  loss =   4.9433  |  lr = 0.00010000
# epoch =    2  |  loss =   4.3142  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6815  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0524  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6994  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9813  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7595  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4393  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1819  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0473  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9171  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7843  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6657  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6094  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5668  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4857  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4574  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4183  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4550, device='cuda:0'), 'MulticlassRecall': tensor(0.5000, device='cuda:0'), 'MulticlassF1Score': tensor(0.4729, device='cuda:0')}
#
# ############################## Trining 10 - 6 ##############################
#
# epoch =    1  |  loss =   5.3592  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1658  |  lr = 0.00009900
# epoch =    3  |  loss =   3.5623  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1824  |  lr = 0.00009703
# epoch =    5  |  loss =   2.5605  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1296  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8157  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5275  |  lr = 0.00009321
# epoch =    9  |  loss =   1.3232  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0344  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9388  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7949  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7205  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6554  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5515  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5067  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4791  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4357  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5545, device='cuda:0'), 'MulticlassRecall': tensor(0.5732, device='cuda:0'), 'MulticlassF1Score': tensor(0.5621, device='cuda:0')}
#
# ############################## Trining 10 - 7 ##############################
#
# epoch =    1  |  loss =   5.3842  |  lr = 0.00010000
# epoch =    2  |  loss =   4.4027  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6900  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1247  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6690  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1106  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7382  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4843  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1947  |  lr = 0.00009227
# epoch =   10  |  loss =   0.9936  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8892  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7492  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7190  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6064  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5393  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5112  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4389  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4169  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4512, device='cuda:0'), 'MulticlassRecall': tensor(0.4756, device='cuda:0'), 'MulticlassF1Score': tensor(0.4631, device='cuda:0')}
#
# ############################## Trining 10 - 8 ##############################
#
# epoch =    1  |  loss =   4.9687  |  lr = 0.00010000
# epoch =    2  |  loss =   4.1117  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6263  |  lr = 0.00009801
# epoch =    4  |  loss =   3.2163  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6049  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0500  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7353  |  lr = 0.00009415
# epoch =    8  |  loss =   1.4030  |  lr = 0.00009321
# epoch =    9  |  loss =   1.1881  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0047  |  lr = 0.00009135
# epoch =   11  |  loss =   0.8760  |  lr = 0.00009044
# epoch =   12  |  loss =   0.7517  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6819  |  lr = 0.00008864
# epoch =   14  |  loss =   0.5786  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5248  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4876  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4725  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4376  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.4863, device='cuda:0'), 'MulticlassRecall': tensor(0.4756, device='cuda:0'), 'MulticlassF1Score': tensor(0.4689, device='cuda:0')}
#
# ############################## Trining 10 - 9 ##############################
#
# epoch =    1  |  loss =   5.5057  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2258  |  lr = 0.00009900
# epoch =    3  |  loss =   3.6622  |  lr = 0.00009801
# epoch =    4  |  loss =   3.1987  |  lr = 0.00009703
# epoch =    5  |  loss =   2.7761  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1730  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7437  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5779  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2626  |  lr = 0.00009227
# epoch =   10  |  loss =   1.0735  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9566  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8451  |  lr = 0.00008953
# epoch =   13  |  loss =   0.6852  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6662  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5744  |  lr = 0.00008687
# epoch =   16  |  loss =   0.5353  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4892  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4568  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5114, device='cuda:0'), 'MulticlassRecall': tensor(0.5000, device='cuda:0'), 'MulticlassF1Score': tensor(0.4968, device='cuda:0')}
#
# ############################## Trining 10 - 10 ##############################
#
# epoch =    1  |  loss =   5.4174  |  lr = 0.00010000
# epoch =    2  |  loss =   4.2344  |  lr = 0.00009900
# epoch =    3  |  loss =   3.7811  |  lr = 0.00009801
# epoch =    4  |  loss =   3.0324  |  lr = 0.00009703
# epoch =    5  |  loss =   2.6298  |  lr = 0.00009606
# epoch =    6  |  loss =   2.1483  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8210  |  lr = 0.00009415
# epoch =    8  |  loss =   1.5537  |  lr = 0.00009321
# epoch =    9  |  loss =   1.2742  |  lr = 0.00009227
# epoch =   10  |  loss =   1.1178  |  lr = 0.00009135
# epoch =   11  |  loss =   0.9128  |  lr = 0.00009044
# epoch =   12  |  loss =   0.8217  |  lr = 0.00008953
# epoch =   13  |  loss =   0.7102  |  lr = 0.00008864
# epoch =   14  |  loss =   0.6422  |  lr = 0.00008775
# epoch =   15  |  loss =   0.5764  |  lr = 0.00008687
# epoch =   16  |  loss =   0.4953  |  lr = 0.00008601
# epoch =   17  |  loss =   0.4861  |  lr = 0.00008515
# epoch =   18  |  loss =   0.4293  |  lr = 0.00008429
# Done
# {'MulticlassPrecision': tensor(0.5270, device='cuda:0'), 'MulticlassRecall': tensor(0.5366, device='cuda:0'), 'MulticlassF1Score': tensor(0.5276, device='cuda:0')}
#
# averages_1481_9.csv saved
