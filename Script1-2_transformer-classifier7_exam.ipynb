# %% [markdown]
# ## 시험 스크립트 1-2 : 스크립트2에서 저장된 데이터셋 10개를 가지고 각각에 대해 10번의 모델 훈련을 수행하며 Precision, Recall, F1-score 과 그 평균 값들을 구해 averages_1481_i.csv 에 저장 (총 100번의 훈련과 각 지표마다 100개의 기록)

# %% [markdown]
# # Multi-Class Classification with Transformer Encoder

# %% [markdown]
# ## 1. Loading helper modules & functions

# %%
# %load_ext autoreload
# %autoreload 2
import torch as T
import torch.nn as nn
import pandas as pd
import numpy as np
import h5py
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import torchinfo
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  # Arrange GPU devices starting from 0
# os.environ["CUDA_VISIBLE_DEVICES"]= "0,1"  # Set the GPU 2 to use
device = T.device("cuda" if T.cuda.is_available() else "cpu")
# device2 = T.device("cuda:1" if T.cuda.is_available() else "cpu")
# device = T.device("cpu")
# from encoding.parallel import DataParallelModel, DataParallelCriterion
from torchmetrics import MetricCollection
from torchmetrics.classification import MulticlassAccuracy, MulticlassPrecision, MulticlassRecall, MulticlassF1Score, MulticlassConfusionMatrix
metric_collection = MetricCollection([
    # MulticlassAccuracy(num_classes=4, average="none").to(device),
    MulticlassPrecision(num_classes=4, average="none").to(device),
    MulticlassRecall(num_classes=4, average="none").to(device),
    MulticlassF1Score(num_classes=4, average="none").to(device),
])
metric_collection_weighted = MetricCollection([
    # MulticlassAccuracy(num_classes=4, average="weighted").to(device),
    MulticlassPrecision(num_classes=4, average="weighted").to(device),
    MulticlassRecall(num_classes=4, average="weighted").to(device),
    MulticlassF1Score(num_classes=4, average="weighted").to(device),
])
# import sklearn.datasets
from sklearn.model_selection import train_test_split
# import umap
# import umap.plot
# import shap
# import scipy as sp
# import transformers
print("Pytorch version:", T.__version__, "CUDA version:", T.version.cuda, "cuDNN version:", T.backends.cudnn.version())
print("device:", device, T.cuda.get_device_name(0), "*", T.cuda.device_count())
# Out:
# Pytorch version: 1.12.1 CUDA version: 11.3 cuDNN version: 8302
# device: cuda Tesla V100-SXM2-32GB * 8

# %% [markdown]
# ## 2. Implementing backbone of Transformer-based Classifier

# %%
# feature 개수 확인 및 설정
hf = h5py.File('STAD_Dataset3_minus_20_exam_0.h5', 'r')
X_DATA = np.array(hf.get('X'))
Y_DATA = np.array(hf.get('Y'))
print('X_DATA.shape :', X_DATA.shape, ', X_DATA.dtype :', X_DATA.dtype)
print('Y_DATA.shape :', Y_DATA.shape, '     , Y_DATA.dtype :', Y_DATA.dtype)
hf.close()

n_feature = X_DATA.shape[1]
print("\nThe number of feature :", n_feature)
# Out:
# X_DATA.shape : (407, 1481) , X_DATA.dtype : float64
# Y_DATA.shape : (407,)      , Y_DATA.dtype : int8
#
# The number of feature : 1481

# %%
class STAD_Dataset(T.utils.data.Dataset):
    def __init__(self, src_file):
        hf = h5py.File(src_file, 'r')
        if 'X_Train' in hf.keys() :
            # x = np.array(hf.get('X_Train')).astype('int64')
            x = np.array(hf.get('X_Train'))
            y = np.array(hf.get('Y_Train')).astype('int8')
        else :
            # x = np.array(hf.get('X_Test')).astype('int64')
            x = np.array(hf.get('X_Test'))
            y = np.array(hf.get('Y_Test')).astype('int8')
        hf.close()

        # self.x_data = T.tensor(x, dtype=T.int64).to(device)
        self.x_data = T.tensor(x, dtype=T.float32).to(device)
        self.y_data = T.tensor(y, dtype=T.int64).to(device)  

    def __len__(self):
        return len(self.x_data)

    def __getitem__(self, idx):
        x = self.x_data[idx]
        y = self.y_data[idx] 
        return x, y

# %%
class PositionalEncoding(T.nn.Module):  
    def __init__(self, d_model: int, dropout: float=0.1, max_len: int=n_feature):
        super(PositionalEncoding, self).__init__()  
        self.dropout = T.nn.Dropout(p=dropout)
        pe = T.zeros(max_len, d_model)  
        position = T.arange(0, max_len, dtype=T.float32).unsqueeze(1)
        div_term = T.exp(T.arange(0, d_model, 2).float() * (-np.log(10_000.0) / d_model))
        pe[:, 0::2] = T.sin(position * div_term)
        pe[:, 1::2] = T.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)  # 이게 없으면 나중에 forward 에서 pe값을 못 찾아 에러남

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

# %%
# E = number of cases that all features can express in integer (feature=token) 
# D = #Embedding Dimension ; I = #input features ; F = #fc1 layer hidden nodes ; drop = dropout rate
E = 320 ; D = 8 ; I = n_feature ; F = 8 ; drop = 0.1
class Transformer_Classifier(T.nn.Module):  # 1501 -> 12008 -> Transformer -> FC -> 4
    def __init__(self):
        super(Transformer_Classifier, self).__init__() 
        # numeric pseudo-embedding, dim=D
        # self.embed = Special_Embedding_Layer(I, I*D)  # I input features, each goes to D 
        self.embed = T.nn.Embedding(E, D)  # I input features, each goes to D
        self.pos_enc = PositionalEncoding(D, dropout=drop)  # positional embedding
        self.enc_layer = T.nn.TransformerEncoderLayer(d_model=D, nhead=4, dim_feedforward=D, 
                         dropout=drop, batch_first=True)  # d_model should be divisible by nhead
        self.trans_enc = T.nn.TransformerEncoder(self.enc_layer, num_layers=3)  # default 6 layers 
        # STAD Dataset has I input features per each sample
        self.dropout = nn.Dropout(drop)
        # self.fc1 = T.nn.Linear(D*I, F)  # F hidden nodes
        # self.fc2 = T.nn.Linear(F, 4)    # 4 classes
        self.fc3 = T.nn.Linear(D*I, 4)    # 4 classes (GX, G1, G2, G3)

    def forward(self, x):
        # x = I input features, fixed length
        z = self.embed(x.int())  # I inputs to I*D embeds
        z = z.reshape(-1, I, D) 
        z = self.pos_enc(z) 
        z = self.trans_enc(z) 
        z = z.reshape(-1, D*I)  # torch.Size([batch_size, D*I])
        # z = self.dropout(z)
        # z = self.fc1(z)
        # z = T.tanh(z)
        z = self.dropout(z)
        z = self.fc3(z)
        z = T.log_softmax(z, dim=1)  # later followed by NLL Loss()
        return z

# %% [markdown]
# ## 3. Training model

# %%
for j in range(10):
    # feature 개수 확인 및 설정
    hf = h5py.File(f'STAD_Dataset3_minus_20_exam_{j}.h5', 'r')
    X_DATA = np.array(hf.get('X'))
    Y_DATA = np.array(hf.get('Y'))
    hf.close()

    print(f'STAD_Dataset3_minus_20_exam_{j}.h5 dataset loaded\n')

    max_F1 = 0
    precision_list_10 = []
    recall_list_10 = []
    f1score_list_10 = []

    for i in range(10):

        print("############################## Trining", j+1, "-", i+1, "##############################\n")

        ########## 3-0. Data Random Splitting ##########

        # 1. Train : Test 를 레이블 비율을 균등하게 유지하면서 8 : 2로 랜덤하게 나눔
        X_Train, X_Test, Y_Train, Y_Test = train_test_split(X_DATA, Y_DATA, test_size=0.2, stratify=Y_DATA, random_state=(2*i+1))

        # 2. Train 데이터 파일로 저장
        hf = h5py.File('STAD_Dataset3_Train_minus_20_exam.h5', 'w')
        hf.create_dataset('X_Train', data=X_Train)
        hf.create_dataset('Y_Train', data=Y_Train)
        hf.close()
        # 3. Test 데이터 파일로 저장 
        hf = h5py.File('STAD_Dataset3_Test_minus_20_exam.h5', 'w')
        hf.create_dataset('X_Test', data=X_Test)
        hf.create_dataset('Y_Test', data=Y_Test)
        hf.close()

        ########## 3-1. Lodaing Dataset ##########

        # 0. setup
        np.random.seed(1)  
        T.manual_seed(1)  

        # 1. create Dataset
        train_file = "./STAD_Dataset3_Train_minus_20_exam.h5"
        train_ds = STAD_Dataset(train_file)

        test_file = "./STAD_Dataset3_Test_minus_20_exam.h5"
        test_ds = STAD_Dataset(test_file)

        bat_size = 32
        train_ldr = T.utils.data.DataLoader(train_ds, batch_size=bat_size, shuffle=True)
        # test_ldr = T.utils.data.DataLoader(test_ds, batch_size=2, shuffle=False)

        ########## 3-2. Training model ##########

        # net = Transformer_Classifier().to(device)
        net = nn.DataParallel(Transformer_Classifier()).to(device)

        max_epochs = 20
        ep_log_interval = 1
        lrn_rate = 0.0001

        loss_func = T.nn.NLLLoss()  # assumes log-softmax()
        # loss_func = DataParallelCriterion(T.nn.NLLLoss())  # assumes log-softmax()
        optimizer = T.optim.Adam(net.parameters(), lr=lrn_rate, weight_decay=0.1)
        scheduler = T.optim.lr_scheduler.LambdaLR(optimizer=optimizer, lr_lambda=lambda epoch: 0.99 ** epoch, last_epoch=-1, verbose=False)

        net.train()  # set mode

        loss_list = []
        accuracy_list = []
        test_accuracy_list = []
        for epoch in range(0, max_epochs):
            ep_loss = 0.0  # for one full epoch
            for (X, y) in train_ldr: # X = genes, y = labels
                optimizer.zero_grad()
                # with T.autocast(device_type="cuda"): # for auto-mixed precision
                oupt = net(X)
                loss_val = loss_func(oupt, y)  # a tensor
                
                ep_loss += loss_val.item()  # accumulate
                loss_val.backward()  # compute grads
                optimizer.step()     # update weights
            if epoch % ep_log_interval == 0:
                print("epoch = %4d  |  loss = %8.4f  |  lr = %8.8f" % (epoch+1, T.cuda.device_count()*ep_loss/bat_size, optimizer.param_groups[0]['lr']))
                # net.eval()
            scheduler.step()

        print("Done ") 

        net.eval()
        with T.no_grad():
            output_test = net(test_ds.x_data)
        target_test = test_ds.y_data
        preds_test  = output_test.argmax(dim=1, keepdim=True).squeeze(1)
        print(metric_collection_weighted(preds_test, target_test),'\n')

        # 시험2를 위한
        precision_list_10.append(MulticlassPrecision(num_classes=4, average="weighted").to(device)(preds_test, target_test))    
        recall_list_10.append(MulticlassRecall(num_classes=4, average="weighted").to(device)(preds_test, target_test))    
        f1score_list_10.append(MulticlassF1Score(num_classes=4, average="weighted").to(device)(preds_test, target_test))    

    ### 10번 훈련에서의 각 precision 값들과 그 평균
    precision_sum = 0
    for p in precision_list_10:
        precision_sum += p
    ### 10번 훈련에서의 각 recall 값들과 그 평균
    recall_sum = 0
    for p in recall_list_10:
        recall_sum += p
    ### 10번 훈련에서의 각 F1-Score 값들과 그 평균
    f1score_sum = 0
    for p in f1score_list_10:
        f1score_sum += p

    ### 각종 값들과 평균 csv 파일로 저장
    precision_list = [p.detach().cpu().numpy() for p in precision_list_10]
    precision_list.append((precision_sum/10).detach().cpu().numpy())
    recall_list = [p.detach().cpu().numpy() for p in recall_list_10]
    recall_list.append((recall_sum/10).detach().cpu().numpy())
    f1score_list = [p.detach().cpu().numpy() for p in f1score_list_10]
    f1score_list.append((f1score_sum/10).detach().cpu().numpy())

    averages_1501_df = pd.DataFrame({'Train':np.arange(1,len(precision_list)+1),
                                    'Precision':precision_list, 
                                    'Recall':recall_list, 
                                    'F1-Score':f1score_list})  
    averages_1501_df.iloc[(-1,0)] = '평균'

    averages_1501_df.to_csv(f'./averages_1481_{j}.csv')
    print(f'averages_1481_{j}.csv saved\n')
# Out:
# STAD_Dataset3_minus_20_exam_0.h5 dataset loaded
#
# ############################## Trining 1 - 1 ##############################
# epoch =    1  |  loss =   2.6771  |  lr = 0.00010000
# epoch =    2  |  loss =   2.6441  |  lr = 0.00009900
# epoch =    3  |  loss =   2.4690  |  lr = 0.00009801
# epoch =    4  |  loss =   2.0691  |  lr = 0.00009703
# epoch =    5  |  loss =   2.1151  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0184  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8437  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7108  |  lr = 0.00009321
# epoch =    9  |  loss =   1.5229  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4947  |  lr = 0.00009135
# epoch =   11  |  loss =   1.2722  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2759  |  lr = 0.00008953
# epoch =   13  |  loss =   1.1885  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1237  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0117  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9521  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9649  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8575  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8057  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7790  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4425, device='cuda:0'), 'MulticlassRecall': tensor(0.5122, device='cuda:0'), 'MulticlassF1Score': tensor(0.4595, device='cuda:0')}
#
# ############################## Trining 1 - 2 ##############################
#
# epoch =    1  |  loss =   2.7868  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5370  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3304  |  lr = 0.00009801
# epoch =    4  |  loss =   2.3029  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0544  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9683  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8653  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7135  |  lr = 0.00009321
# epoch =    9  |  loss =   1.5664  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5366  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4246  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3843  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2511  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1644  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0307  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9939  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9992  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8847  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8861  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7605  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4960, device='cuda:0'), 'MulticlassRecall': tensor(0.5854, device='cuda:0'), 'MulticlassF1Score': tensor(0.4726, device='cuda:0')}
#
# ############################## Trining 1 - 3 ##############################
#
# epoch =    1  |  loss =   2.8793  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5680  |  lr = 0.00009900
# epoch =    3  |  loss =   2.2818  |  lr = 0.00009801
# epoch =    4  |  loss =   2.3930  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0332  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9889  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8369  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6881  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6614  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5293  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4857  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3900  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2657  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1343  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0612  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9921  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9593  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8958  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8350  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8274  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.5011, device='cuda:0'), 'MulticlassRecall': tensor(0.5610, device='cuda:0'), 'MulticlassF1Score': tensor(0.5035, device='cuda:0')}
#
# ############################## Trining 1 - 4 ##############################
#
# epoch =    1  |  loss =   2.7285  |  lr = 0.00010000
# epoch =    2  |  loss =   2.4050  |  lr = 0.00009900
# epoch =    3  |  loss =   2.4266  |  lr = 0.00009801
# epoch =    4  |  loss =   2.4255  |  lr = 0.00009703
# epoch =    5  |  loss =   2.1089  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9295  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8915  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8579  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6651  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4467  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4088  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2888  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2443  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1075  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0931  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0204  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9563  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9332  |  lr = 0.00008429
# epoch =   19  |  loss =   0.9041  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8081  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4878, device='cuda:0'), 'MulticlassRecall': tensor(0.5610, device='cuda:0'), 'MulticlassF1Score': tensor(0.4829, device='cuda:0')}
#
# ############################## Trining 1 - 5 ##############################
#
# epoch =    1  |  loss =   2.7720  |  lr = 0.00010000
# epoch =    2  |  loss =   2.7005  |  lr = 0.00009900
# epoch =    3  |  loss =   2.2481  |  lr = 0.00009801
# epoch =    4  |  loss =   2.0899  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9892  |  lr = 0.00009606
# epoch =    6  |  loss =   1.8919  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8051  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7457  |  lr = 0.00009321
# epoch =    9  |  loss =   1.5769  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5092  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4416  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2748  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2203  |  lr = 0.00008864
# epoch =   14  |  loss =   1.0412  |  lr = 0.00008775
# epoch =   15  |  loss =   0.9758  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9132  |  lr = 0.00008601
# epoch =   17  |  loss =   0.8759  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8095  |  lr = 0.00008429
# epoch =   19  |  loss =   0.7783  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7588  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.3942, device='cuda:0'), 'MulticlassRecall': tensor(0.4512, device='cuda:0'), 'MulticlassF1Score': tensor(0.4154, device='cuda:0')}
#
# ############################## Trining 1 - 6 ##############################
#
# epoch =    1  |  loss =   2.8730  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5340  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3761  |  lr = 0.00009801
# epoch =    4  |  loss =   2.1617  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9758  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0956  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7720  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8597  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6768  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5809  |  lr = 0.00009135
# epoch =   11  |  loss =   1.6366  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3337  |  lr = 0.00008953
# epoch =   13  |  loss =   1.3037  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1448  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0726  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9613  |  lr = 0.00008601
# epoch =   17  |  loss =   0.8940  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8388  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8209  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7862  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4957, device='cuda:0'), 'MulticlassRecall': tensor(0.5488, device='cuda:0'), 'MulticlassF1Score': tensor(0.5109, device='cuda:0')}
#
# ############################## Trining 1 - 7 ##############################
#
# epoch =    1  |  loss =   3.3407  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5183  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3303  |  lr = 0.00009801
# epoch =    4  |  loss =   2.2316  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0308  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9986  |  lr = 0.00009510
# epoch =    7  |  loss =   2.0471  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8796  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6364  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5259  |  lr = 0.00009135
# epoch =   11  |  loss =   1.3867  |  lr = 0.00009044
# epoch =   12  |  loss =   1.4702  |  lr = 0.00008953
# epoch =   13  |  loss =   1.3885  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1586  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0788  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0438  |  lr = 0.00008601
# epoch =   17  |  loss =   1.0010  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8718  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8422  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7839  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.3923, device='cuda:0'), 'MulticlassRecall': tensor(0.4634, device='cuda:0'), 'MulticlassF1Score': tensor(0.4164, device='cuda:0')}
#
# ############################## Trining 1 - 8 ##############################
#
# epoch =    1  |  loss =   2.6578  |  lr = 0.00010000
# epoch =    2  |  loss =   2.7044  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3336  |  lr = 0.00009801
# epoch =    4  |  loss =   2.0563  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0751  |  lr = 0.00009606
# epoch =    6  |  loss =   1.8828  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8065  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7026  |  lr = 0.00009321
# epoch =    9  |  loss =   1.5199  |  lr = 0.00009227
# epoch =   10  |  loss =   1.3916  |  lr = 0.00009135
# epoch =   11  |  loss =   1.3429  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2396  |  lr = 0.00008953
# epoch =   13  |  loss =   1.3104  |  lr = 0.00008864
# epoch =   14  |  loss =   1.0962  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0304  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9430  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9042  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8227  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8003  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7710  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.5325, device='cuda:0'), 'MulticlassRecall': tensor(0.5854, device='cuda:0'), 'MulticlassF1Score': tensor(0.5110, device='cuda:0')}
#
# ############################## Trining 1 - 9 ##############################
#
# epoch =    1  |  loss =   3.1969  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5990  |  lr = 0.00009900
# epoch =    3  |  loss =   2.4250  |  lr = 0.00009801
# epoch =    4  |  loss =   2.3680  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0473  |  lr = 0.00009606
# epoch =    6  |  loss =   1.8983  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7572  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7631  |  lr = 0.00009321
# epoch =    9  |  loss =   1.7117  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5989  |  lr = 0.00009135
# epoch =   11  |  loss =   1.5463  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3765  |  lr = 0.00008953
# epoch =   13  |  loss =   1.4078  |  lr = 0.00008864
# epoch =   14  |  loss =   1.2261  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1232  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0535  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9926  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9955  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8968  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8897  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4651, device='cuda:0'), 'MulticlassRecall': tensor(0.5122, device='cuda:0'), 'MulticlassF1Score': tensor(0.4839, device='cuda:0')}
#
# ############################## Trining 1 - 10 ##############################
#
# epoch =    1  |  loss =   2.7384  |  lr = 0.00010000
# epoch =    2  |  loss =   2.9204  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3924  |  lr = 0.00009801
# epoch =    4  |  loss =   2.2852  |  lr = 0.00009703
# epoch =    5  |  loss =   2.3307  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0240  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8448  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7757  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6804  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5867  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4470  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3843  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2961  |  lr = 0.00008864
# epoch =   14  |  loss =   1.2127  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1976  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0822  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9907  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9312  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8904  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8519  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.3614, device='cuda:0'), 'MulticlassRecall': tensor(0.5000, device='cuda:0'), 'MulticlassF1Score': tensor(0.4058, device='cuda:0')}
#
# averages_1481_0.csv saved
#
# STAD_Dataset3_minus_20_exam_1.h5 dataset loaded
#
# ############################## Trining 2 - 1 ##############################
#
# epoch =    1  |  loss =   2.6255  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5135  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3051  |  lr = 0.00009801
# epoch =    4  |  loss =   1.9992  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9065  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9811  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7426  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6214  |  lr = 0.00009321
# epoch =    9  |  loss =   1.4120  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4013  |  lr = 0.00009135
# epoch =   11  |  loss =   1.2014  |  lr = 0.00009044
# epoch =   12  |  loss =   1.1973  |  lr = 0.00008953
# epoch =   13  |  loss =   1.0722  |  lr = 0.00008864
# epoch =   14  |  loss =   1.0544  |  lr = 0.00008775
# epoch =   15  |  loss =   0.9747  |  lr = 0.00008687
# epoch =   16  |  loss =   0.8955  |  lr = 0.00008601
# epoch =   17  |  loss =   0.8906  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8030  |  lr = 0.00008429
# epoch =   19  |  loss =   0.7905  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7376  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.5533, device='cuda:0'), 'MulticlassRecall': tensor(0.5976, device='cuda:0'), 'MulticlassF1Score': tensor(0.5475, device='cuda:0')}
#
# ############################## Trining 2 - 2 ##############################
#
# epoch =    1  |  loss =   2.8190  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5405  |  lr = 0.00009900
# epoch =    3  |  loss =   2.2877  |  lr = 0.00009801
# epoch =    4  |  loss =   2.1835  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0638  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9352  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7926  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6651  |  lr = 0.00009321
# epoch =    9  |  loss =   1.5657  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5361  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4222  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3401  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2583  |  lr = 0.00008864
# epoch =   14  |  loss =   1.2021  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0726  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9726  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9683  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8806  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8631  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7996  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4685, device='cuda:0'), 'MulticlassRecall': tensor(0.5732, device='cuda:0'), 'MulticlassF1Score': tensor(0.4655, device='cuda:0')}
#
# ############################## Trining 2 - 3 ##############################
#
# epoch =    1  |  loss =   2.7924  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5633  |  lr = 0.00009900
# epoch =    3  |  loss =   2.2807  |  lr = 0.00009801
# epoch =    4  |  loss =   2.3207  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0236  |  lr = 0.00009606
# epoch =    6  |  loss =   1.8996  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7353  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6336  |  lr = 0.00009321
# epoch =    9  |  loss =   1.5864  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4590  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4601  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3072  |  lr = 0.00008953
# epoch =   13  |  loss =   1.1825  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1033  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0766  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9835  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9098  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8350  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8303  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7791  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4030, device='cuda:0'), 'MulticlassRecall': tensor(0.4512, device='cuda:0'), 'MulticlassF1Score': tensor(0.4220, device='cuda:0')}
#
# ############################## Trining 2 - 4 ##############################
#
# epoch =    1  |  loss =   2.7255  |  lr = 0.00010000
# epoch =    2  |  loss =   2.3882  |  lr = 0.00009900
# epoch =    3  |  loss =   2.4867  |  lr = 0.00009801
# epoch =    4  |  loss =   2.4605  |  lr = 0.00009703
# epoch =    5  |  loss =   2.1541  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9008  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8403  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7958  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6021  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4520  |  lr = 0.00009135
# epoch =   11  |  loss =   1.3814  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3354  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2413  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1160  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0882  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0077  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9593  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9059  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8860  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8235  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4793, device='cuda:0'), 'MulticlassRecall': tensor(0.5610, device='cuda:0'), 'MulticlassF1Score': tensor(0.4846, device='cuda:0')}
#
# ############################## Trining 2 - 5 ##############################
#
# epoch =    1  |  loss =   2.6797  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5656  |  lr = 0.00009900
# epoch =    3  |  loss =   2.1607  |  lr = 0.00009801
# epoch =    4  |  loss =   2.0128  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9754  |  lr = 0.00009606
# epoch =    6  |  loss =   1.8568  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7071  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6656  |  lr = 0.00009321
# epoch =    9  |  loss =   1.4565  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4227  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4252  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2553  |  lr = 0.00008953
# epoch =   13  |  loss =   1.1708  |  lr = 0.00008864
# epoch =   14  |  loss =   1.0422  |  lr = 0.00008775
# epoch =   15  |  loss =   0.9653  |  lr = 0.00008687
# epoch =   16  |  loss =   0.8473  |  lr = 0.00008601
# epoch =   17  |  loss =   0.8061  |  lr = 0.00008515
# epoch =   18  |  loss =   0.7940  |  lr = 0.00008429
# epoch =   19  |  loss =   0.7743  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7157  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4260, device='cuda:0'), 'MulticlassRecall': tensor(0.5244, device='cuda:0'), 'MulticlassF1Score': tensor(0.4491, device='cuda:0')}
#
# ############################## Trining 2 - 6 ##############################
#
# epoch =    1  |  loss =   2.8360  |  lr = 0.00010000
# epoch =    2  |  loss =   2.4963  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3653  |  lr = 0.00009801
# epoch =    4  |  loss =   2.1040  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9414  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0326  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7781  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8594  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6360  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4658  |  lr = 0.00009135
# epoch =   11  |  loss =   1.5686  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2820  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2144  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1205  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0509  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9302  |  lr = 0.00008601
# epoch =   17  |  loss =   0.8885  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8334  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8461  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8020  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.5791, device='cuda:0'), 'MulticlassRecall': tensor(0.6098, device='cuda:0'), 'MulticlassF1Score': tensor(0.5940, device='cuda:0')}
#
# ############################## Trining 2 - 7 ##############################
#
# epoch =    1  |  loss =   3.1846  |  lr = 0.00010000
# epoch =    2  |  loss =   2.4036  |  lr = 0.00009900
# epoch =    3  |  loss =   2.2958  |  lr = 0.00009801
# epoch =    4  |  loss =   2.1535  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9601  |  lr = 0.00009606
# epoch =    6  |  loss =   1.8779  |  lr = 0.00009510
# epoch =    7  |  loss =   2.0024  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8515  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6634  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5574  |  lr = 0.00009135
# epoch =   11  |  loss =   1.3555  |  lr = 0.00009044
# epoch =   12  |  loss =   1.4467  |  lr = 0.00008953
# epoch =   13  |  loss =   1.3183  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1801  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1056  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0513  |  lr = 0.00008601
# epoch =   17  |  loss =   1.0224  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8770  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8611  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7375  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4217, device='cuda:0'), 'MulticlassRecall': tensor(0.4756, device='cuda:0'), 'MulticlassF1Score': tensor(0.4422, device='cuda:0')}
#
# ############################## Trining 2 - 8 ##############################
#
# epoch =    1  |  loss =   2.6090  |  lr = 0.00010000
# epoch =    2  |  loss =   2.7041  |  lr = 0.00009900
# epoch =    3  |  loss =   2.2854  |  lr = 0.00009801
# epoch =    4  |  loss =   2.0712  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0551  |  lr = 0.00009606
# epoch =    6  |  loss =   1.8408  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7564  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6950  |  lr = 0.00009321
# epoch =    9  |  loss =   1.5328  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4104  |  lr = 0.00009135
# epoch =   11  |  loss =   1.3480  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2714  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2910  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1188  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0050  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9381  |  lr = 0.00008601
# epoch =   17  |  loss =   0.8907  |  lr = 0.00008515
# epoch =   18  |  loss =   0.7928  |  lr = 0.00008429
# epoch =   19  |  loss =   0.7703  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7141  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.5691, device='cuda:0'), 'MulticlassRecall': tensor(0.6098, device='cuda:0'), 'MulticlassF1Score': tensor(0.5706, device='cuda:0')}
#
# ############################## Trining 2 - 9 ##############################
#
# epoch =    1  |  loss =   2.9931  |  lr = 0.00010000
# epoch =    2  |  loss =   2.4731  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3095  |  lr = 0.00009801
# epoch =    4  |  loss =   2.3013  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0050  |  lr = 0.00009606
# epoch =    6  |  loss =   1.8092  |  lr = 0.00009510
# epoch =    7  |  loss =   1.6822  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7527  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6057  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4653  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4670  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2822  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2884  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1219  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0261  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0020  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9713  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9428  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8559  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8239  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4831, device='cuda:0'), 'MulticlassRecall': tensor(0.5122, device='cuda:0'), 'MulticlassF1Score': tensor(0.4971, device='cuda:0')}
#
# ############################## Trining 2 - 10 ##############################
#
# epoch =    1  |  loss =   2.7051  |  lr = 0.00010000
# epoch =    2  |  loss =   2.9112  |  lr = 0.00009900
# epoch =    3  |  loss =   2.4026  |  lr = 0.00009801
# epoch =    4  |  loss =   2.1919  |  lr = 0.00009703
# epoch =    5  |  loss =   2.2527  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9255  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8590  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7603  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6799  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5623  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4550  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3391  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2825  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1909  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1568  |  lr = 0.00008687
# epoch =   16  |  loss =   1.1000  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9739  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8799  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8956  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8105  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4408, device='cuda:0'), 'MulticlassRecall': tensor(0.5122, device='cuda:0'), 'MulticlassF1Score': tensor(0.4612, device='cuda:0')}
#
# averages_1481_1.csv saved
#
# STAD_Dataset3_minus_20_exam_2.h5 dataset loaded
#
# ############################## Trining 3 - 1 ##############################
#
# epoch =    1  |  loss =   2.6161  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5444  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3849  |  lr = 0.00009801
# epoch =    4  |  loss =   1.9873  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9643  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9753  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8210  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6711  |  lr = 0.00009321
# epoch =    9  |  loss =   1.4326  |  lr = 0.00009227
# epoch =   10  |  loss =   1.3919  |  lr = 0.00009135
# epoch =   11  |  loss =   1.2212  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2447  |  lr = 0.00008953
# epoch =   13  |  loss =   1.0948  |  lr = 0.00008864
# epoch =   14  |  loss =   1.0635  |  lr = 0.00008775
# epoch =   15  |  loss =   0.9925  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9117  |  lr = 0.00008601
# epoch =   17  |  loss =   0.8867  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8118  |  lr = 0.00008429
# epoch =   19  |  loss =   0.7753  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7253  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4953, device='cuda:0'), 'MulticlassRecall': tensor(0.5610, device='cuda:0'), 'MulticlassF1Score': tensor(0.4939, device='cuda:0')}
#
# ############################## Trining 3 - 2 ##############################
#
# epoch =    1  |  loss =   2.8126  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5698  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3641  |  lr = 0.00009801
# epoch =    4  |  loss =   2.2519  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0926  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0035  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8294  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7065  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6107  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5418  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4677  |  lr = 0.00009044
# epoch =   12  |  loss =   1.4450  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2819  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1848  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1010  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0274  |  lr = 0.00008601
# epoch =   17  |  loss =   1.0037  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9188  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8816  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7945  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4367, device='cuda:0'), 'MulticlassRecall': tensor(0.5732, device='cuda:0'), 'MulticlassF1Score': tensor(0.4489, device='cuda:0')}
#
# ############################## Trining 3 - 3 ##############################
#
# epoch =    1  |  loss =   2.8496  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5733  |  lr = 0.00009900
# epoch =    3  |  loss =   2.2724  |  lr = 0.00009801
# epoch =    4  |  loss =   2.3111  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0563  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9752  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7492  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6934  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6393  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5079  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4838  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3383  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2294  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1206  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1025  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0101  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9627  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8781  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8467  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8229  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4852, device='cuda:0'), 'MulticlassRecall': tensor(0.5244, device='cuda:0'), 'MulticlassF1Score': tensor(0.5010, device='cuda:0')}
#
# ############################## Trining 3 - 4 ##############################
#
# epoch =    1  |  loss =   2.6926  |  lr = 0.00010000
# epoch =    2  |  loss =   2.4671  |  lr = 0.00009900
# epoch =    3  |  loss =   2.5390  |  lr = 0.00009801
# epoch =    4  |  loss =   2.4592  |  lr = 0.00009703
# epoch =    5  |  loss =   2.1450  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9609  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8809  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8285  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6878  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4936  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4615  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3725  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2918  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1496  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0986  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0342  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9841  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9510  |  lr = 0.00008429
# epoch =   19  |  loss =   0.9396  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8535  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.5641, device='cuda:0'), 'MulticlassRecall': tensor(0.6098, device='cuda:0'), 'MulticlassF1Score': tensor(0.5292, device='cuda:0')}
#
# ############################## Trining 3 - 5 ##############################
#
# epoch =    1  |  loss =   2.7570  |  lr = 0.00010000
# epoch =    2  |  loss =   2.6725  |  lr = 0.00009900
# epoch =    3  |  loss =   2.2091  |  lr = 0.00009801
# epoch =    4  |  loss =   2.0793  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9803  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9551  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7800  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7672  |  lr = 0.00009321
# epoch =    9  |  loss =   1.5562  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4837  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4640  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2880  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2333  |  lr = 0.00008864
# epoch =   14  |  loss =   1.0936  |  lr = 0.00008775
# epoch =   15  |  loss =   0.9938  |  lr = 0.00008687
# epoch =   16  |  loss =   0.8961  |  lr = 0.00008601
# epoch =   17  |  loss =   0.8398  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8201  |  lr = 0.00008429
# epoch =   19  |  loss =   0.7874  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7699  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.3013, device='cuda:0'), 'MulticlassRecall': tensor(0.4268, device='cuda:0'), 'MulticlassF1Score': tensor(0.3532, device='cuda:0')}
#
# ############################## Trining 3 - 6 ##############################
#
# epoch =    1  |  loss =   2.8221  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5499  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3606  |  lr = 0.00009801
# epoch =    4  |  loss =   2.1145  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9716  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0288  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7999  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8362  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6695  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5147  |  lr = 0.00009135
# epoch =   11  |  loss =   1.5841  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3110  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2517  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1159  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0705  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9350  |  lr = 0.00008601
# epoch =   17  |  loss =   0.8926  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8221  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8358  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7990  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.5691, device='cuda:0'), 'MulticlassRecall': tensor(0.6098, device='cuda:0'), 'MulticlassF1Score': tensor(0.5706, device='cuda:0')}
#
# ############################## Trining 3 - 7 ##############################
#
# epoch =    1  |  loss =   3.2496  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5122  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3875  |  lr = 0.00009801
# epoch =    4  |  loss =   2.2356  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9946  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9952  |  lr = 0.00009510
# epoch =    7  |  loss =   2.0243  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8838  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6158  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5993  |  lr = 0.00009135
# epoch =   11  |  loss =   1.3844  |  lr = 0.00009044
# epoch =   12  |  loss =   1.5006  |  lr = 0.00008953
# epoch =   13  |  loss =   1.4294  |  lr = 0.00008864
# epoch =   14  |  loss =   1.2224  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1631  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0902  |  lr = 0.00008601
# epoch =   17  |  loss =   1.0421  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9286  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8732  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7740  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.3841, device='cuda:0'), 'MulticlassRecall': tensor(0.4146, device='cuda:0'), 'MulticlassF1Score': tensor(0.3982, device='cuda:0')}
#
# ############################## Trining 3 - 8 ##############################
#
# epoch =    1  |  loss =   2.6155  |  lr = 0.00010000
# epoch =    2  |  loss =   2.6764  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3262  |  lr = 0.00009801
# epoch =    4  |  loss =   2.0655  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0448  |  lr = 0.00009606
# epoch =    6  |  loss =   1.8556  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7482  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6978  |  lr = 0.00009321
# epoch =    9  |  loss =   1.5835  |  lr = 0.00009227
# epoch =   10  |  loss =   1.3752  |  lr = 0.00009135
# epoch =   11  |  loss =   1.3334  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2630  |  lr = 0.00008953
# epoch =   13  |  loss =   1.3361  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1464  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0353  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9486  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9087  |  lr = 0.00008515
# epoch =   18  |  loss =   0.7969  |  lr = 0.00008429
# epoch =   19  |  loss =   0.7696  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7621  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4773, device='cuda:0'), 'MulticlassRecall': tensor(0.5610, device='cuda:0'), 'MulticlassF1Score': tensor(0.4704, device='cuda:0')}
#
# ############################## Trining 3 - 9 ##############################
#
# epoch =    1  |  loss =   3.0531  |  lr = 0.00010000
# epoch =    2  |  loss =   2.4551  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3345  |  lr = 0.00009801
# epoch =    4  |  loss =   2.2581  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9877  |  lr = 0.00009606
# epoch =    6  |  loss =   1.8321  |  lr = 0.00009510
# epoch =    7  |  loss =   1.6654  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7803  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6401  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4684  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4799  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2919  |  lr = 0.00008953
# epoch =   13  |  loss =   1.3633  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1163  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0738  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9602  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9404  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9479  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8314  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8021  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4674, device='cuda:0'), 'MulticlassRecall': tensor(0.5244, device='cuda:0'), 'MulticlassF1Score': tensor(0.4871, device='cuda:0')}
#
# ############################## Trining 3 - 10 ##############################
#
# epoch =    1  |  loss =   2.7773  |  lr = 0.00010000
# epoch =    2  |  loss =   2.8430  |  lr = 0.00009900
# epoch =    3  |  loss =   2.4039  |  lr = 0.00009801
# epoch =    4  |  loss =   2.2596  |  lr = 0.00009703
# epoch =    5  |  loss =   2.2592  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9538  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8146  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7599  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6817  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5581  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4889  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3840  |  lr = 0.00008953
# epoch =   13  |  loss =   1.3126  |  lr = 0.00008864
# epoch =   14  |  loss =   1.2217  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1548  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0810  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9917  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8950  |  lr = 0.00008429
# epoch =   19  |  loss =   0.9076  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8303  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4668, device='cuda:0'), 'MulticlassRecall': tensor(0.5610, device='cuda:0'), 'MulticlassF1Score': tensor(0.4723, device='cuda:0')}
#
# averages_1481_2.csv saved
#
# STAD_Dataset3_minus_20_exam_3.h5 dataset loaded
#
# ############################## Trining 4 - 1 ##############################
#
# epoch =    1  |  loss =   2.6352  |  lr = 0.00010000
# epoch =    2  |  loss =   2.6975  |  lr = 0.00009900
# epoch =    3  |  loss =   2.4519  |  lr = 0.00009801
# epoch =    4  |  loss =   2.0536  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0889  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9815  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8273  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7341  |  lr = 0.00009321
# epoch =    9  |  loss =   1.5000  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4790  |  lr = 0.00009135
# epoch =   11  |  loss =   1.2995  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3356  |  lr = 0.00008953
# epoch =   13  |  loss =   1.1592  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1090  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0362  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9809  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9537  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8614  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8294  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7913  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4153, device='cuda:0'), 'MulticlassRecall': tensor(0.5122, device='cuda:0'), 'MulticlassF1Score': tensor(0.4413, device='cuda:0')}
#
# ############################## Trining 4 - 2 ##############################
#
# epoch =    1  |  loss =   2.8833  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5962  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3591  |  lr = 0.00009801
# epoch =    4  |  loss =   2.2851  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0689  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9962  |  lr = 0.00009510
# epoch =    7  |  loss =   1.9128  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7306  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6383  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5838  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4644  |  lr = 0.00009044
# epoch =   12  |  loss =   1.4534  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2930  |  lr = 0.00008864
# epoch =   14  |  loss =   1.2113  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1092  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0131  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9673  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8905  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8924  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8140  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4702, device='cuda:0'), 'MulticlassRecall': tensor(0.5854, device='cuda:0'), 'MulticlassF1Score': tensor(0.4554, device='cuda:0')}
#
# ############################## Trining 4 - 3 ##############################
#
# epoch =    1  |  loss =   2.9268  |  lr = 0.00010000
# epoch =    2  |  loss =   2.6453  |  lr = 0.00009900
# epoch =    3  |  loss =   2.2659  |  lr = 0.00009801
# epoch =    4  |  loss =   2.3456  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0887  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9431  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8471  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7243  |  lr = 0.00009321
# epoch =    9  |  loss =   1.7192  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5613  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4835  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3952  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2508  |  lr = 0.00008864
# epoch =   14  |  loss =   1.2156  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1064  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0322  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9900  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9273  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8590  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8583  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4922, device='cuda:0'), 'MulticlassRecall': tensor(0.5244, device='cuda:0'), 'MulticlassF1Score': tensor(0.5073, device='cuda:0')}
#
# ############################## Trining 4 - 4 ##############################
#
# epoch =    1  |  loss =   2.7934  |  lr = 0.00010000
# epoch =    2  |  loss =   2.4745  |  lr = 0.00009900
# epoch =    3  |  loss =   2.4813  |  lr = 0.00009801
# epoch =    4  |  loss =   2.4652  |  lr = 0.00009703
# epoch =    5  |  loss =   2.1860  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0010  |  lr = 0.00009510
# epoch =    7  |  loss =   1.9522  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8486  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6657  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5016  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4552  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3315  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2654  |  lr = 0.00008864
# epoch =   14  |  loss =   1.2182  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1540  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0583  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9926  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9063  |  lr = 0.00008429
# epoch =   19  |  loss =   0.9166  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7917  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.5011, device='cuda:0'), 'MulticlassRecall': tensor(0.5610, device='cuda:0'), 'MulticlassF1Score': tensor(0.5035, device='cuda:0')}
#
# ############################## Trining 4 - 5 ##############################
#
# epoch =    1  |  loss =   2.8639  |  lr = 0.00010000
# epoch =    2  |  loss =   2.6927  |  lr = 0.00009900
# epoch =    3  |  loss =   2.2730  |  lr = 0.00009801
# epoch =    4  |  loss =   2.1240  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0113  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9552  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8407  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8055  |  lr = 0.00009321
# epoch =    9  |  loss =   1.5961  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5733  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4925  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3155  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2126  |  lr = 0.00008864
# epoch =   14  |  loss =   1.0522  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0412  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9378  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9169  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8336  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8098  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7968  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4957, device='cuda:0'), 'MulticlassRecall': tensor(0.5488, device='cuda:0'), 'MulticlassF1Score': tensor(0.5109, device='cuda:0')}
#
# ############################## Trining 4 - 6 ##############################
#
# epoch =    1  |  loss =   2.8932  |  lr = 0.00010000
# epoch =    2  |  loss =   2.4608  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3533  |  lr = 0.00009801
# epoch =    4  |  loss =   2.1695  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9645  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0751  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8087  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8457  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6600  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5782  |  lr = 0.00009135
# epoch =   11  |  loss =   1.5826  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3323  |  lr = 0.00008953
# epoch =   13  |  loss =   1.3425  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1156  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0570  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0022  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9239  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8683  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8595  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7941  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.5003, device='cuda:0'), 'MulticlassRecall': tensor(0.5488, device='cuda:0'), 'MulticlassF1Score': tensor(0.5181, device='cuda:0')}
#
# ############################## Trining 4 - 7 ##############################
#
# epoch =    1  |  loss =   3.3545  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5161  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3693  |  lr = 0.00009801
# epoch =    4  |  loss =   2.2155  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0338  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9676  |  lr = 0.00009510
# epoch =    7  |  loss =   2.0411  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8738  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6890  |  lr = 0.00009227
# ...
# Done
# {'MulticlassPrecision': tensor(0.5011, device='cuda:0'), 'MulticlassRecall': tensor(0.5610, device='cuda:0'), 'MulticlassF1Score': tensor(0.5035, device='cuda:0')}
#
# ############################## Trining 9 - 9 ##############################
#
# epoch =    1  |  loss =   3.2030  |  lr = 0.00010000
# epoch =    2  |  loss =   2.6380  |  lr = 0.00009900
# epoch =    3  |  loss =   2.4937  |  lr = 0.00009801
# epoch =    4  |  loss =   2.3447  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0183  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9057  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7719  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7759  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6999  |  lr = 0.00009227
# epoch =   10  |  loss =   1.6236  |  lr = 0.00009135
# epoch =   11  |  loss =   1.6282  |  lr = 0.00009044
# epoch =   12  |  loss =   1.4061  |  lr = 0.00008953
# epoch =   13  |  loss =   1.3784  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1922  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1142  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0538  |  lr = 0.00008601
# epoch =   17  |  loss =   1.0603  |  lr = 0.00008515
# epoch =   18  |  loss =   1.0369  |  lr = 0.00008429
# epoch =   19  |  loss =   0.9514  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8873  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4775, device='cuda:0'), 'MulticlassRecall': tensor(0.5122, device='cuda:0'), 'MulticlassF1Score': tensor(0.4934, device='cuda:0')}
#
# ############################## Trining 9 - 10 ##############################
#
# epoch =    1  |  loss =   2.7355  |  lr = 0.00010000
# epoch =    2  |  loss =   2.8856  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3735  |  lr = 0.00009801
# epoch =    4  |  loss =   2.3247  |  lr = 0.00009703
# epoch =    5  |  loss =   2.2794  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0180  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8630  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7746  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6501  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5358  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4637  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3885  |  lr = 0.00008953
# epoch =   13  |  loss =   1.3312  |  lr = 0.00008864
# epoch =   14  |  loss =   1.2517  |  lr = 0.00008775
# epoch =   15  |  loss =   1.2018  |  lr = 0.00008687
# epoch =   16  |  loss =   1.1046  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9699  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9134  |  lr = 0.00008429
# epoch =   19  |  loss =   0.9003  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8376  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4627, device='cuda:0'), 'MulticlassRecall': tensor(0.5366, device='cuda:0'), 'MulticlassF1Score': tensor(0.4783, device='cuda:0')}
#
# averages_1481_8.csv saved
#
# STAD_Dataset3_minus_20_exam_9.h5 dataset loaded
#
# ############################## Trining 10 - 1 ##############################
#
# epoch =    1  |  loss =   2.6416  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5975  |  lr = 0.00009900
# epoch =    3  |  loss =   2.4008  |  lr = 0.00009801
# epoch =    4  |  loss =   2.0423  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0403  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9902  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7898  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6809  |  lr = 0.00009321
# epoch =    9  |  loss =   1.4751  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4360  |  lr = 0.00009135
# epoch =   11  |  loss =   1.2251  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3102  |  lr = 0.00008953
# epoch =   13  |  loss =   1.1227  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1127  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0316  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9368  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9044  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8399  |  lr = 0.00008429
# epoch =   19  |  loss =   0.7917  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7471  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4539, device='cuda:0'), 'MulticlassRecall': tensor(0.5244, device='cuda:0'), 'MulticlassF1Score': tensor(0.4682, device='cuda:0')}
#
# ############################## Trining 10 - 2 ##############################
#
# epoch =    1  |  loss =   2.7990  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5912  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3238  |  lr = 0.00009801
# epoch =    4  |  loss =   2.2236  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0395  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9822  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8669  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7060  |  lr = 0.00009321
# epoch =    9  |  loss =   1.5842  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5492  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4854  |  lr = 0.00009044
# epoch =   12  |  loss =   1.4121  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2800  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1753  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0900  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0003  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9804  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8745  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8723  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7766  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.6271, device='cuda:0'), 'MulticlassRecall': tensor(0.6098, device='cuda:0'), 'MulticlassF1Score': tensor(0.5013, device='cuda:0')}
#
# ############################## Trining 10 - 3 ##############################
#
# epoch =    1  |  loss =   2.9036  |  lr = 0.00010000
# epoch =    2  |  loss =   2.6036  |  lr = 0.00009900
# epoch =    3  |  loss =   2.2087  |  lr = 0.00009801
# epoch =    4  |  loss =   2.3386  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0648  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9803  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7940  |  lr = 0.00009415
# epoch =    8  |  loss =   1.6867  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6304  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4959  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4920  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3228  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2060  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1718  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0752  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0116  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9650  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8892  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8474  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8336  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4702, device='cuda:0'), 'MulticlassRecall': tensor(0.5122, device='cuda:0'), 'MulticlassF1Score': tensor(0.4864, device='cuda:0')}
#
# ############################## Trining 10 - 4 ##############################
#
# epoch =    1  |  loss =   2.7411  |  lr = 0.00010000
# epoch =    2  |  loss =   2.4811  |  lr = 0.00009900
# epoch =    3  |  loss =   2.5378  |  lr = 0.00009801
# epoch =    4  |  loss =   2.4856  |  lr = 0.00009703
# epoch =    5  |  loss =   2.1500  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9455  |  lr = 0.00009510
# epoch =    7  |  loss =   1.9326  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8733  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6507  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4601  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4464  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3415  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2817  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1657  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1278  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0454  |  lr = 0.00008601
# epoch =   17  |  loss =   1.0058  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9877  |  lr = 0.00008429
# epoch =   19  |  loss =   0.9487  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8340  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.3922, device='cuda:0'), 'MulticlassRecall': tensor(0.5366, device='cuda:0'), 'MulticlassF1Score': tensor(0.4263, device='cuda:0')}
#
# ############################## Trining 10 - 5 ##############################
#
# epoch =    1  |  loss =   2.7682  |  lr = 0.00010000
# epoch =    2  |  loss =   2.6514  |  lr = 0.00009900
# epoch =    3  |  loss =   2.2510  |  lr = 0.00009801
# epoch =    4  |  loss =   2.0785  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0183  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9209  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7658  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7474  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6003  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4877  |  lr = 0.00009135
# epoch =   11  |  loss =   1.4273  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2802  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2283  |  lr = 0.00008864
# epoch =   14  |  loss =   1.0540  |  lr = 0.00008775
# epoch =   15  |  loss =   0.9979  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9047  |  lr = 0.00008601
# epoch =   17  |  loss =   0.8582  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8058  |  lr = 0.00008429
# epoch =   19  |  loss =   0.7607  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7286  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.3200, device='cuda:0'), 'MulticlassRecall': tensor(0.5000, device='cuda:0'), 'MulticlassF1Score': tensor(0.3902, device='cuda:0')}
#
# ############################## Trining 10 - 6 ##############################
#
# epoch =    1  |  loss =   2.8631  |  lr = 0.00010000
# epoch =    2  |  loss =   2.5013  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3112  |  lr = 0.00009801
# epoch =    4  |  loss =   2.1118  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9535  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0537  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7687  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7824  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6370  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5341  |  lr = 0.00009135
# epoch =   11  |  loss =   1.6062  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2745  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2424  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1411  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0553  |  lr = 0.00008687
# epoch =   16  |  loss =   0.9441  |  lr = 0.00008601
# epoch =   17  |  loss =   0.8936  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8467  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8296  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7910  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4929, device='cuda:0'), 'MulticlassRecall': tensor(0.5488, device='cuda:0'), 'MulticlassF1Score': tensor(0.5027, device='cuda:0')}
#
# ############################## Trining 10 - 7 ##############################
#
# epoch =    1  |  loss =   3.2923  |  lr = 0.00010000
# epoch =    2  |  loss =   2.4943  |  lr = 0.00009900
# epoch =    3  |  loss =   2.2732  |  lr = 0.00009801
# epoch =    4  |  loss =   2.1672  |  lr = 0.00009703
# epoch =    5  |  loss =   1.9970  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9368  |  lr = 0.00009510
# epoch =    7  |  loss =   1.9740  |  lr = 0.00009415
# epoch =    8  |  loss =   1.8220  |  lr = 0.00009321
# epoch =    9  |  loss =   1.6074  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5480  |  lr = 0.00009135
# epoch =   11  |  loss =   1.3382  |  lr = 0.00009044
# epoch =   12  |  loss =   1.4762  |  lr = 0.00008953
# epoch =   13  |  loss =   1.3482  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1643  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0954  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0532  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9829  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8760  |  lr = 0.00008429
# epoch =   19  |  loss =   0.8417  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7840  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4046, device='cuda:0'), 'MulticlassRecall': tensor(0.4268, device='cuda:0'), 'MulticlassF1Score': tensor(0.4154, device='cuda:0')}
#
# ############################## Trining 10 - 8 ##############################
#
# epoch =    1  |  loss =   2.6999  |  lr = 0.00010000
# epoch =    2  |  loss =   2.8193  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3582  |  lr = 0.00009801
# epoch =    4  |  loss =   2.1137  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0793  |  lr = 0.00009606
# epoch =    6  |  loss =   1.9024  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7586  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7279  |  lr = 0.00009321
# epoch =    9  |  loss =   1.5870  |  lr = 0.00009227
# epoch =   10  |  loss =   1.4289  |  lr = 0.00009135
# epoch =   11  |  loss =   1.3809  |  lr = 0.00009044
# epoch =   12  |  loss =   1.2935  |  lr = 0.00008953
# epoch =   13  |  loss =   1.2988  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1131  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0604  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0017  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9328  |  lr = 0.00008515
# epoch =   18  |  loss =   0.8124  |  lr = 0.00008429
# epoch =   19  |  loss =   0.7891  |  lr = 0.00008345
# epoch =   20  |  loss =   0.7657  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4871, device='cuda:0'), 'MulticlassRecall': tensor(0.5488, device='cuda:0'), 'MulticlassF1Score': tensor(0.4946, device='cuda:0')}
#
# ############################## Trining 10 - 9 ##############################
#
# epoch =    1  |  loss =   3.1756  |  lr = 0.00010000
# epoch =    2  |  loss =   2.6173  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3423  |  lr = 0.00009801
# epoch =    4  |  loss =   2.3524  |  lr = 0.00009703
# epoch =    5  |  loss =   2.0394  |  lr = 0.00009606
# epoch =    6  |  loss =   1.8352  |  lr = 0.00009510
# epoch =    7  |  loss =   1.7338  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7803  |  lr = 0.00009321
# epoch =    9  |  loss =   1.7038  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5516  |  lr = 0.00009135
# epoch =   11  |  loss =   1.5641  |  lr = 0.00009044
# epoch =   12  |  loss =   1.3888  |  lr = 0.00008953
# epoch =   13  |  loss =   1.3878  |  lr = 0.00008864
# epoch =   14  |  loss =   1.1851  |  lr = 0.00008775
# epoch =   15  |  loss =   1.0969  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0653  |  lr = 0.00008601
# epoch =   17  |  loss =   1.0287  |  lr = 0.00008515
# epoch =   18  |  loss =   1.0104  |  lr = 0.00008429
# epoch =   19  |  loss =   0.9420  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8494  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.5206, device='cuda:0'), 'MulticlassRecall': tensor(0.5610, device='cuda:0'), 'MulticlassF1Score': tensor(0.5377, device='cuda:0')}
#
# ############################## Trining 10 - 10 ##############################
#
# epoch =    1  |  loss =   2.7819  |  lr = 0.00010000
# epoch =    2  |  loss =   2.9585  |  lr = 0.00009900
# epoch =    3  |  loss =   2.3427  |  lr = 0.00009801
# epoch =    4  |  loss =   2.2983  |  lr = 0.00009703
# epoch =    5  |  loss =   2.3312  |  lr = 0.00009606
# epoch =    6  |  loss =   2.0426  |  lr = 0.00009510
# epoch =    7  |  loss =   1.8932  |  lr = 0.00009415
# epoch =    8  |  loss =   1.7858  |  lr = 0.00009321
# epoch =    9  |  loss =   1.7062  |  lr = 0.00009227
# epoch =   10  |  loss =   1.5514  |  lr = 0.00009135
# epoch =   11  |  loss =   1.5394  |  lr = 0.00009044
# epoch =   12  |  loss =   1.4179  |  lr = 0.00008953
# epoch =   13  |  loss =   1.3086  |  lr = 0.00008864
# epoch =   14  |  loss =   1.2562  |  lr = 0.00008775
# epoch =   15  |  loss =   1.1703  |  lr = 0.00008687
# epoch =   16  |  loss =   1.0855  |  lr = 0.00008601
# epoch =   17  |  loss =   0.9826  |  lr = 0.00008515
# epoch =   18  |  loss =   0.9108  |  lr = 0.00008429
# epoch =   19  |  loss =   0.9067  |  lr = 0.00008345
# epoch =   20  |  loss =   0.8444  |  lr = 0.00008262
# Done
# {'MulticlassPrecision': tensor(0.4176, device='cuda:0'), 'MulticlassRecall': tensor(0.5122, device='cuda:0'), 'MulticlassF1Score': tensor(0.4392, device='cuda:0')}
#
# averages_1481_9.csv saved
